# %%
from keras.applications.xception import Xception
from keras.layers import GlobalAveragePooling2D, Dense, Flatten
from keras.models import Sequential
#from keras.optimizers import SGD
#import numpy as np
# Out:
# 2022-11-29 14:01:04.987886: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def base_model():
    base_model = Xception(weights="imagenet",input_shape = (180,320,3),include_top=False)
    base_model.trainable = False
    return base_model

# %%
base_model()
# Out:
# 2022-11-29 14:01:12.807809: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def complete_model():
    model = Sequential((
        base_model(),
        GlobalAveragePooling2D(),
        Flatten(),
        Dense(50,activation = 'relu'),
        Dense(1,activation = 'linear')))
    
    model.compile(loss="mse", optimizer='adam',
                  metrics=["mae"])
    
    return model

# %%
model = complete_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 6, 10, 2048)       20861480
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 50)                102450
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 20,963,981
# Trainable params: 102,501
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
from ipynb.fs.defs.NF_dataloading import dataloading
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 from ipynb.fs.defs.NF_dataloading import dataloading
#
# File ~/code/jacksharples1/youtube_optimizer/NF_dataloading.ipynb:52
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "7ca7e609",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import os\n",
#      11     "import matplotlib.pyplot as plt\n",
#      12     "from sklearn.model_selection import train_test_split\n",
#      13     "import numpy as np"
#      14    ]
#      15   },
#      16   {
#      17    "cell_type": "code",
#      18    "execution_count": 2,
#      19    "id": "42634f19",
#      20    "metadata": {},
#      21    "outputs": [],
#      22    "source": [
#      23     "from google.cloud import storage\n",
#      24     "from google.oauth2 import service_account"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": 3,
#      30    "id": "368544d2",
#      31    "metadata": {},
#      32    "outputs": [],
#      33    "source": [
#      34     "def get_images_to_folder():\n",
#      35     "    BUCKET_NAME = \"youtube_optimizer_data\"\n",
#      36     "    storage_dir = \"thumbnail_images\"\n",
#      37     "    local_dir = \"bucket_data/\" #Create this manually\n",
#      38     "\n",
#      39     "    my_credentials = service_account.Credentials.from_service_account_file(\"massive-pen-365111-8eaed18fb748.json\")\n",
#      40     "\n",
#      41     "    client = storage.Client(credentials=my_credentials)\n",
#      42     "    bucket = client.bucket(BUCKET_NAME)\n",
#      43     "    blob = bucket.blob(storage_dir)\n",
#      44     "    \n",
#      45     "    blobs = bucket.list_blobs(prefix =storage_dir)\n",
#      46     "    for blob in blobs:\n",
#      47     "        filename = blob.name.replace('/','_')\n",
#      48     "        blob.download_to_filename(local_dir + filename)"
#      49    ]
#      50   },
#      51   {
# ---> 52    "cell_type": "code",
#      53    "execution_count": 4,
#      54    "id": "aa933d7d",
#      55    "metadata": {},
#      56    "outputs": [
#      57     {
#      58      "data": {
#      59       "text/plain": [
#      60        "17"
#      61       ]
#      62      },
#      63      "execution_count": 4,
#      64      "metadata": {},
#      65      "output_type": "execute_result"
#      66     }
#      67    ],
#      68    "source": [
#      69     "len('thumbnail_images_')"
#      70    ]
#      71   },
#      72   {
#      73    "cell_type": "code",
#      74    "execution_count": 5,
#      75    "id": "aa19a993",
#      76    "metadata": {},
#      77    "outputs": [],
#      78    "source": [
#      79     "def load_images_from_folder(folder='/Users/nicolafriedrich/code/jacksharples1/youtube_optimizer/bucket_data'):\n",
#      80     "    images = []\n",
#      81     "    views = []\n",
#      82     "    for filename in os.listdir(folder):\n",
#      83     "        if len(filename)< 18:\n",
#      84     "            continue\n",
#      85     "\n",
#      86     "        else:\n",
#      87     "            img = plt.imread(os.path.join(folder,filename))\n",
#      88     "            last_underscore = filename.rfind('_')\n",
#      89     "            y = int(filename[last_underscore +1:])\n",
#      90     "            images.append(np.array(img))\n",
#      91     "            views.append(y)\n",
#      92     "    return images, views\n"
#      93    ]
#      94   },
#      95   {
#      96    "cell_type": "code",
#      97    "execution_count": 6,
#      98    "id": "e7b02d2b",
#      99    "metadata": {},
#     100    "outputs": [],
#     101    "source": [
#     102     "imgs,views = load_images_from_folder()"
#     103    ]
#     104   },
#     105   {
#     106    "cell_type": "code",
#     107    "execution_count": 7,
#     108    "id": "063bda60",
#     109    "metadata": {},
#     110    "outputs": [
#     111     {
#     112      "data": {
#     113       "text/plain": [
#     114        "(633, (180, 320, 3), list, numpy.ndarray)"
#     115       ]
#     116      },
#     117      "execution_count": 7,
#     118      "metadata": {},
#     119      "output_type": "execute_result"
#     120     }
#     121    ],
#     122    "source": [
#     123     "len(imgs),imgs[0].shape,type(imgs),type(imgs[0])"
#     124    ]
#     125   },
#     126   {
#     127    "cell_type": "code",
#     128    "execution_count": 8,
#     129    "id": "6831a134",
#     130    "metadata": {},
#     131    "outputs": [],
#     132    "source": [
#     133     "X = imgs\n",
#     134     "y = views"
#     135    ]
#     136   },
#     137   {
#     138    "cell_type": "code",
#     139    "execution_count": 9,
#     140    "id": "c8d01802",
#     141    "metadata": {},
#     142    "outputs": [],
#     143    "source": [
#     144     "def split_train_test(X,y,test_size = 0.3, random_state = 0):\n",
#     145     "    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)\n",
#     146     "    X_train = np.asarray(X_train).astype(np.float32)\n",
#     147     "    y_train = np.asarray(y_train).astype(np.float32)\n",
#     148     "    X_test = np.asarray(X_test).astype(np.float32)\n",
#     149     "    y_test = np.asarray(y_test).astype(np.float32)\n",
#     150     "    return X_train, X_test, y_train, y_test"
#     151    ]
#     152   },
#     153   {
#     154    "cell_type": "code",
#     155    "execution_count": null,
#     156    "id": "846f2335",
#     157    "metadata": {},
#     158    "outputs": [],
#     159    "source": []
#     160   },
#     161   {
#     162    "cell_type": "code",
#     163    "execution_count": 10,
#     164    "id": "ad9ab578",
#     165    "metadata": {},
#     166    "outputs": [],
#     167    "source": [
#     168     "def dataloading():\n",
#     169     "    get_images_to_folder()\n",
#     170     "    X,y = load_images_from_folder()\n",
#     171     "    X_train, X_test, y_train, y_test = split_train_test(X,y)\n",
#     172     "    return X_train, X_test, y_train, y_test"
#     173    ]
#     174   },
#     175   {
#     176    "cell_type": "code",
#     177    "execution_count": 11,
#     178    "id": "cd938bb5",
#     179    "metadata": {},
#     180    "outputs": [
#     181     {
#     182      "name": "stderr",
#     183      "output_type": "stream",
#     184      "text": [
#     185       "/var/folders/5h/c46twxvs23df7jrx5ql_wh3r0000gn/T/ipykernel_10834/1114826248.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.\n",
#     186       "  X_train = np.asarray(X_train).astype(np.float32)\n"
#     187      ]
#     188     },
#     189     {
#     190      "ename": "ValueError",
#     191      "evalue": "setting an array element with a sequence.",
#     192      "output_type": "error",
#     193      "traceback": [
#     194       "\u001b---------------------------------------------------------------------------\u001b",
#     195       "\u001bTypeError\u001b                                 Traceback (most recent call last)",
#     196       "\u001bTypeError\u001b: only size-1 arrays can be converted to Python scalars",
#     197       "\nThe above exception was the direct cause of the following exception:\n",
#     198       "\u001bValueError\u001b                                Traceback (most recent call last)",
#     199       "Cell \u001bIn [11], line 1\u001b\n\u001b----> 1\u001b X_train, X_test, y_train, y_test \u001b=\u001b dataloading()\n",
#     200       "Cell \u001bIn [10], line 4\u001b, in \u001bdataloading\u001b()\u001b\n\u001b      2\u001b get_images_to_folder()\n\u001b      3\u001b X,y \u001b=\u001b load_images_from_folder()\n\u001b----> 4\u001b X_train, X_test, y_train, y_test \u001b=\u001b \u001bsplit_train_test\u001b\u001b(\u001b\u001bX\u001b\u001b,\u001b\u001by\u001b\u001b)\u001b\n\u001b      5\u001b \u001breturn\u001b X_train, X_test, y_train, y_test\n",
#     201       "Cell \u001bIn [9], line 3\u001b, in \u001bsplit_train_test\u001b(X, y, test_size, random_state)\u001b\n\u001b      1\u001b \u001bdef\u001b \u001bsplit_train_test\u001b(X,y,test_size \u001b=\u001b \u001b0.3\u001b, random_state \u001b=\u001b \u001b0\u001b):\n\u001b      2\u001b     X_train, X_test, y_train, y_test \u001b=\u001b train_test_split(X, y, test_size\u001b=\u001b\u001b0.3\u001b, random_state\u001b=\u001b\u001b0\u001b)\n\u001b----> 3\u001b     X_train \u001b=\u001b \u001bnp\u001b\u001b.\u001b\u001basarray\u001b\u001b(\u001b\u001bX_train\u001b\u001b)\u001b\u001b.\u001b\u001bastype\u001b\u001b(\u001b\u001bnp\u001b\u001b.\u001b\u001bfloat32\u001b\u001b)\u001b\n\u001b      4\u001b     y_train \u001b=\u001b np\u001b.\u001basarray(y_train)\u001b.\u001bastype(np\u001b.\u001bfloat32)\n\u001b      5\u001b     X_test \u001b=\u001b np\u001b.\u001basarray(X_test)\u001b.\u001bastype(np\u001b.\u001bfloat32)\n",
#     202       "\u001bValueError\u001b: setting an array element with a sequence."
#     203      ]
#     204     }
#     205    ],
#     206    "source": [
#     207     "X_train, X_test, y_train, y_test = dataloading()"
#     208    ]
#     209   },
#     210   {
#     211    "cell_type": "code",
#     212    "execution_count": null,
#     213    "id": "66173c27",
#     214    "metadata": {},
#     215    "outputs": [],
#     216    "source": [
#     217     "X_train = np.array(X_train)\n",
#     218     "y_train = np.array(y_train)"
#     219    ]
#     220   },
#     221   {
#     222    "cell_type": "code",
#     223    "execution_count": null,
#     224    "id": "a4517035",
#     225    "metadata": {},
#     226    "outputs": [],
#     227    "source": [
#     228     "len(X_train)"
#     229    ]
#     230   },
#     231   {
#     232    "cell_type": "code",
#     233    "execution_count": null,
#     234    "id": "e2016d63",
#     235    "metadata": {},
#     236    "outputs": [],
#     237    "source": [
#     238     "X_train[0].shape"
#     239    ]
#     240   },
#     241   {
#     242    "cell_type": "code",
#     243    "execution_count": null,
#     244    "id": "97073f54",
#     245    "metadata": {},
#     246    "outputs": [],
#     247    "source": [
#     248     "X_train.shape"
#     249    ]
#     250   },
#     251   {
#     252    "cell_type": "code",
#     253    "execution_count": null,
#     254    "id": "a0a5499a",
#     255    "metadata": {},
#     256    "outputs": [],
#     257    "source": [
#     258     "type(X_train)"
#     259    ]
#     260   },
#     261   {
#     262    "cell_type": "code",
#     263    "execution_count": null,
#     264    "id": "e58a8db3",
#     265    "metadata": {},
#     266    "outputs": [],
#     267    "source": [
#     268     "type(X_train[0])"
#     269    ]
#     270   },
#     271   {
#     272    "cell_type": "code",
#     273    "execution_count": null,
#     274    "id": "04cbc8bc",
#     275    "metadata": {},
#     276    "outputs": [],
#     277    "source": [
#     278     "type(X_train[0][0])"
#     279    ]
#     280   },
#     281   {
#     282    "cell_type": "code",
#     283    "execution_count": null,
#     284    "id": "a579fd0b",
#     285    "metadata": {},
#     286    "outputs": [],
#     287    "source": [
#     288     "type(X_train[0][0][0])"
#     289    ]
#     290   },
#     291   {
#     292    "cell_type": "code",
#     293    "execution_count": null,
#     294    "id": "79d135de",
#     295    "metadata": {},
#     296    "outputs": [],
#     297    "source": [
#     298     "type(X_train[0][0][0][0])"
#     299    ]
#     300   }
#     301  ],
#     302  "metadata": {
#     303   "kernelspec": {
#     304    "display_name": "Python 3 (ipykernel)",
#     305    "language": "python",
#     306    "name": "python3"
#     307   },
#     308   "language_info": {
#     309    "codemirror_mode": {
#     310     "name": "ipython",
#     311     "version": 3
#     312    },
#     313    "file_extension": ".py",
#     314    "mimetype": "text/x-python",
#     315    "name": "python",
#     316    "nbconvert_exporter": "python",
#     317    "pygments_lexer": "ipython3",
#     318    "version": "3.10.6"
#     319   },
#     320   "toc": {
#     321    "base_numbering": 1,
#     322    "nav_menu": {},
#     323    "number_sections": true,
#     324    "sideBar": true,
#     325    "skip_h1_title": false,
#     326    "title_cell": "Table of Contents",
#     327    "title_sidebar": "Contents",
#     328    "toc_cell": false,
#     329    "toc_position": {},
#     330    "toc_section_display": true,
#     331    "toc_window_display": false
#     332   }
#     333  },
#     334  "nbformat": 4,
#     335  "nbformat_minor": 5
#     336 }
#
# NameError: name 'imgs' is not defined

# %%
X_train, X_test, y_train, y_test = dataloading()

# %%
type(X_train),type(y_train)

# %%
import numpy as np

# %%
np.zeros(10)

# %%
#X_train

# %%
#np.unique(X_train)

# %%
model.fit(X_train,y_train, epochs = 5)
