# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2.tar.gz (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 4.9 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.1 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: matplotlib in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: packaging>=20.0 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Users/billy/.pyenv/versions/3.10.6/envs/youtube-optimizer/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.8.2.2-cp310-cp310-macosx_11_0_arm64.whl size=155788 sha256=7ad4f7613758c80f7f7f43eb11ab126f0057149460e900f98afabed762596ce1
#   Stored in directory: /Users/billy/Library/Caches/pip/wheels/30/52/73/36458d38e3c533678a3043949ad72658025d8e89d942439d49
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
#
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
from wordcloud import STOPWORDS
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

# %%
import string
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv('/Users/billy/code/copy folder/youtube_optimizer/RawData/finalesterest.csv')

# %%
from math import log

# %%
df_copy = df.copy()

# %%
df_copy.views = df_copy.views.apply(lambda x: log(x+1))

# %%
plt.hist(df_copy.views, bins=40);

# %%
df.views.min()
# Out:
# 0

# %%
df.views.max()
# Out:
# 118885715

# %%
len(df)
# Out:
# 21430

# %%
ten_percent= int(len(df)/10)

df_top10 = df.nlargest(ten_percent, 'views')

# %%
df_top10
# Out:
#        Unnamed: 0.1  Unnamed: 0           id                channel_id  \
# 17998          7027           0  7Wmq2XZptQw  UCF5Rp2ghzXsX6vwYqa7aepg
# 1470           1470           0  7Wmq2XZptQw  UCF5Rp2ghzXsX6vwYqa7aepg
# 7999           7999           0  mMkKMFGEWlE  UCg0e8IQiJ62_t2Aef1woA0Q
# 6829           6829           0  qmWwrT91rfY  UCoGForHQAmk0_9rI9CABeYw
# 16863          5892           0  _y5XsdEUPpI  UCY-at5vWhDoMJ8y0kIPFwDA
# ...             ...         ...          ...                       ...
# 6431           6431           0  8UeCIhKG2FQ  UCq18eeL7D9Vd8DhjMcLh9QQ
# 3752           3752           0  MMf5Fz7Tn_I  UCsCy3274qvLzrbq9vGYLCpg
# 14013          3042           0  5SRnfCBN9Cs  UCNAf1k0yIjyGu3k9BwAg3lg
# 600             600           0  MMf5Fz7Tn_I  UCsCy3274qvLzrbq9vGYLCpg
# 250             250           0  MMf5Fz7Tn_I  UCsCy3274qvLzrbq9vGYLCpg
#
#        category_id country  channel_viewCount  channel_subscriberCount  \
# 17998         26.0      US       9.077534e+08                1450000.0
# 1470          26.0      US       9.077534e+08                1440000.0
# 7999          28.0      IN       1.587888e+08                2340000.0
# 6829          24.0      GB       7.978823e+09               10700000.0
# 16863         24.0      IN       7.873238e+09               15500000.0
# ...            ...     ...                ...                      ...
# 6431          24.0      GB       9.927235e+08                1140000.0
# 3752          27.0      US       4.697463e+07                 184000.0
# 14013         17.0      GB       2.945686e+09                4140000.0
# 600           27.0      US       4.697463e+07                 184000.0
# 250           27.0      US       4.697463e+07                 184000.0
#
#        channel_videoCount                                              title  \
# 17998               809.0          Ripped your pants? Not a problem! #shorts
# 1470                807.0          Ripped your pants? Not a problem! #shorts
# 7999                123.0  wait for end l #shorts #whatif  #uniqueexperim...
# 6829                767.0                  The perfect dotted line challenge
# 16863               465.0       Family love ❤️🥺 #shorts #azhan5star #youtube
# ...                   ...                                                ...
# 6431              10667.0  Susanna Reid Shuts Down Just Stop Oil Activist...
# 3752                 96.0  Windstorm in the Desert +More | Super Rescue T...
# 14013              8165.0  Ramsey scores to ease pressure off Gerrard | A...
# 600                  96.0  Windstorm in the Desert +More | Super Rescue T...
# 250                  96.0  Windstorm in the Desert +More | Super Rescue T...
#
#                   published      views  duration
# 17998  2022-11-09T16:25:29Z  118885715     PT59S
# 1470   2022-11-09T16:25:29Z  117382677     PT59S
# 7999   2022-11-07T13:12:31Z   74294612     PT55S
# 6829   2022-11-10T09:51:21Z   71271941    PT1M1S
# 16863  2022-10-31T10:57:54Z   70209597      PT1M
# ...                     ...        ...       ...
# 6431   2022-11-09T13:20:03Z     447335   PT9M33S
# 3752   2022-11-11T12:00:22Z     446809  PT50M27S
# 14013  2022-09-16T21:21:46Z     446675   PT2M37S
# 600    2022-11-11T12:00:22Z     446349  PT50M27S
# 250    2022-11-11T12:00:22Z     446333  PT50M27S
#
# [2143 rows x 13 columns]

# %%
plt.hist(df_top10.views, bins=20);

# %%
def text_cleaner_and_splitter(text):
    return (text.lower()
            .replace('❤️', ' heart ').replace('💯', ' 100 ').replace('❤', ' heart ')
            .replace('🙏', ' pray ').replace('😘', ' kiss ').replace('🤗', ' happy ')
            .replace('💥', ' boom ').replace('✔️', ' like ').replace('😍', ' love ')
            .replace('🐱', ' cat ').replace('💔', ' broken heart ').replace('😵', ' confused ') 
            .replace('😄', ' awesome ').replace('👍', ' thumbs up ').replace('😎', ' cool ')
            .replace('🐷', ' pig ').replace('🤘', " rock'n roll ").replace('🤣', ' laughing hard ')
            .replace('😩', ' oh no ').replace('💎', ' diamond ').replace('😊', ' nice ')
            .replace('☺️', ' very nice ').replace('🙃', ' upside down smile ').replace('🤔', ' not sure ')
            .replace('😂', ' laughing ').replace('🙋🏻‍♀️',' hi ').replace('🥰', ' lovely ').replace('🥺',' sad ')
            .replace('!!!!', '!').replace('!!!', '!').replace('!!', '!').replace('!',' ! ')
            .replace('????', '?').replace('???', '?').replace('??', '?').replace('?',' ? ')
            .replace('oooo','o').replace('oooo','o').replace('ooo','o')
            .replace('..','...').replace('......','...').replace('....','...').replace('....','...').replace('...',' ... ')
            .replace('.',' . ').replace('. . .', ' ... ')
            .replace("'", " ").replace('"', ' ')
            .replace('    ', ' ').replace('   ', ' ').replace('  ', ' '))
            #.split())

# %%
def preprocessing(sentence):
#     Lower
    sentence = sentence.lower()

#     punctuation
    for punctuation in string.punctuation:
        sentence = sentence.replace(punctuation, '')

#   no numbers
    sentence = ''.join(char for char in sentence if not char.isdigit())

#     sentence = emoji_strip(sentence)

    clean_titles = lemmatize(sentence)

    return clean_titles

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def lemmatize(text):
    # Lemmatizing the verbs
    verb_lemmatized = [
        WordNetLemmatizer().lemmatize(word, pos = "v") # v --> verbs
        for word in text
    ]

# 2 - Lemmatizing the nouns
    noun_lemmatized = [
        WordNetLemmatizer().lemmatize(word, pos = "n") # n --> nouns
        for word in text
    ]
    return text

# %%
df_top10.title = df_top10.title.apply(text_cleaner_and_splitter)

# %%
df_top10.head()
# Out:
#        Unnamed: 0.1  Unnamed: 0           id                channel_id  \
# 17998          7027           0  7Wmq2XZptQw  UCF5Rp2ghzXsX6vwYqa7aepg
# 1470           1470           0  7Wmq2XZptQw  UCF5Rp2ghzXsX6vwYqa7aepg
# 7999           7999           0  mMkKMFGEWlE  UCg0e8IQiJ62_t2Aef1woA0Q
# 6829           6829           0  qmWwrT91rfY  UCoGForHQAmk0_9rI9CABeYw
# 16863          5892           0  _y5XsdEUPpI  UCY-at5vWhDoMJ8y0kIPFwDA
#
#        category_id country  channel_viewCount  channel_subscriberCount  \
# 17998         26.0      US       9.077534e+08                1450000.0
# 1470          26.0      US       9.077534e+08                1440000.0
# 7999          28.0      IN       1.587888e+08                2340000.0
# 6829          24.0      GB       7.978823e+09               10700000.0
# 16863         24.0      IN       7.873238e+09               15500000.0
#
#        channel_videoCount                                              title  \
# 17998               809.0        ripped your pants ? not a problem ! #shorts
# 1470                807.0        ripped your pants ? not a problem ! #shorts
# 7999                123.0  wait for end l #shorts #whatif #uniqueexperime...
# 6829                767.0                  the perfect dotted line challenge
# 16863               465.0  family love heart sad #shorts #azhan5star #you...
#
#                   published      views duration
# 17998  2022-11-09T16:25:29Z  118885715    PT59S
# 1470   2022-11-09T16:25:29Z  117382677    PT59S
# 7999   2022-11-07T13:12:31Z   74294612    PT55S
# 6829   2022-11-10T09:51:21Z   71271941   PT1M1S
# 16863  2022-10-31T10:57:54Z   70209597     PT1M

# %%
df_top10.title = df_top10.title.apply(preprocessing)

# %%
df_top10.head()
# Out:
#        Unnamed: 0.1  Unnamed: 0           id                channel_id  \
# 17998          7027           0  7Wmq2XZptQw  UCF5Rp2ghzXsX6vwYqa7aepg
# 1470           1470           0  7Wmq2XZptQw  UCF5Rp2ghzXsX6vwYqa7aepg
# 7999           7999           0  mMkKMFGEWlE  UCg0e8IQiJ62_t2Aef1woA0Q
# 6829           6829           0  qmWwrT91rfY  UCoGForHQAmk0_9rI9CABeYw
# 16863          5892           0  _y5XsdEUPpI  UCY-at5vWhDoMJ8y0kIPFwDA
#
#        category_id country  channel_viewCount  channel_subscriberCount  \
# 17998         26.0      US       9.077534e+08                1450000.0
# 1470          26.0      US       9.077534e+08                1440000.0
# 7999          28.0      IN       1.587888e+08                2340000.0
# 6829          24.0      GB       7.978823e+09               10700000.0
# 16863         24.0      IN       7.873238e+09               15500000.0
#
#        channel_videoCount                                              title  \
# 17998               809.0           ripped your pants  not a problem  shorts
# 1470                807.0           ripped your pants  not a problem  shorts
# 7999                123.0  wait for end l shorts whatif uniqueexperiment ...
# 6829                767.0                  the perfect dotted line challenge
# 16863               465.0     family love heart sad shorts azhanstar youtube
#
#                   published      views duration
# 17998  2022-11-09T16:25:29Z  118885715    PT59S
# 1470   2022-11-09T16:25:29Z  117382677    PT59S
# 7999   2022-11-07T13:12:31Z   74294612    PT55S
# 6829   2022-11-10T09:51:21Z   71271941   PT1M1S
# 16863  2022-10-31T10:57:54Z   70209597     PT1M

# %%
def smash(df):
    bigguns = df.title.tolist()
    joined_bigguns = ' '.join(x for x in bigguns)
    return joined_bigguns

# %%
all_text = smash(df_top10)

# %%
stripped_all = text_cleaner_and_splitter(all_text)
stripped_all
# Out:
# 'ripped your pants not a problem shorts ripped your pants not a problem shorts wait for end l shorts whatif uniqueexperiment majedar the perfect dotted line challenge family love heart sad shorts azhanstar youtube cute love story love heart gulshan kalra shorts how to hold a newborn like a pro the baby doctorshorts ytshorts babyvideos tipsandtricks taking care of mommy long legs make up transformation by one more shorts taking care of mommy long legs make up transformation by one more shorts taking care of mommy long legs make up transformation by one more shorts taking care of mommy long legs make up transformation by one more shorts tom and jerry rithviampkavijim 🏋️ end twist laughing shorts how moses really split the red sea 🌊 🤯 dekho last m kya huashorts trending viral thegeetagurjar youtubeshorts giving my old drawing a ‘glow up’✨\U0001fae3 inspired by uno afrah giving my old drawing a ‘glow up’✨\U0001fae3 inspired by uno afrah woh measurements lene ayaa hain srikanta hoichoi i cant believe this actually happened😱 listen to “destination” by crash adams link in comments🔥 i cant believe this actually happened😱 listen to “destination” by crash adams link in comments🔥 i cant believe this actually happened😱 listen to “destination” by crash adams link in comments🔥 what was she thinking laughing hard shorts girls birthday vs boys birthday chimkandi chimkandi new video atif fc new video shorts girls birthday vs boys birthday chimkandi chimkandi new video atif fc new video shorts takdaa rawaan video sachet tandon parampara tandon kumaar adil shaikh bhushan kumar takdaa rawaan video sachet tandon parampara tandon kumaar adil shaikh bhushan kumar 🔴 cocomelon songs live wheels on the bus more nursery rhymes amp kids songs 🔴 cocomelon songs live wheels on the bus more nursery rhymes amp kids songs 🔴 cocomelon songs live wheels on the bus more nursery rhymes amp kids songs 🔴 cocomelon songs live wheels on the bus more nursery rhymes amp kids songs we got super powers guess the hero challenge which lighter next not sure we got super powers guess the hero challenge sidhu moose wala vaar science class failed me laughing poor kid and mean girl sad 👻 heart shorts poor kid and mean girl sad 👻 heart shorts science experiment sunny bhaiya ka paiya shorts fip sunnysirscience how many blue takis can i eat an action hero official trailer ayushmann khurrana jaideep a aanand l rai anirudh bhushan k respect love 🔥 love hard 😨 laughing shorts my name is with new heroes d billions kids songs my name is with new heroes d billions kids songs my name is with new heroes d billions kids songs my name is with new heroes d billions kids songs my name is with new heroes d billions kids songs indoor playground song more nursery rhymes family fun time with ball pit trampoline slides amptoys girls hostel official trailer th november ahsaas channa parul gulati sony liv originals when boyfriend finally leaves 💃🏻 shorts cutest love story love heart shorts cutelovestory cutest love story love heart shorts cutelovestory good vs bad which are you laughing 🖤 shorts you can get this set of cleaning tools in the commentshomelife you can get this set of cleaning tools in the commentshomelife darkest stain ever 🤯 गाडी का चक्कर 🛵😆 badi behen choti behen part shorts shorts break wood crack repair shorts doodlebob is back spongebob short art craft i bought the worlds rarest puppy paw patrol mighty pups on a the roll wheels on the busold macdonald had a farm animal sounds song snake sneaky steal adorable baby bird from nest mother bird attack snake madly to protect her child लड़के वाले देखने आ रहे हैं comedy per second shorts jokes comedy jjs treehouse song more nursery rhymes amp kids songs hours of cocomelon mixing every cold glitters in slime jjs treehouse song more nursery rhymes amp kids songs hours of cocomelon she came home to surprise her brother after not seeing him for years heart 👏 she came home to surprise her brother after not seeing him for years heart 👏 chotu dad ...

# %%
from wordcloud import STOPWORDS

# %%
type(STOPWORDS)
# Out:
# set

# %%
updated = ['short', 'amp', 'v', 'video', 'shorts', 'dhar']
STOPWORDS.update(updated)

# %%
len(STOPWORDS)
# Out:
# 206

# %%
wc = WordCloud(background_color="white", max_words=2000,
               stopwords=STOPWORDS, max_font_size=256,
               random_state=42, width=500, height=500)
wc.generate(stripped_all)
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
def one_color_func(word=None, font_size=None, 
                   position=None, orientation=None, 
                   font_path=None, random_state=None):
    h = 5 # 0 - 360
    s = 83 # 0 - 100
    l = 53 # 0 - 100
    return "hsl({}, {}%, {}%)".format(h, s, l)

# %%
wc = WordCloud(stopwords=STOPWORDS,
               background_color="white",
               max_words=2000, max_font_size=256,
               random_state=42, color_func=one_color_func)
wc.generate(stripped_all)
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# font_path = 'path/to/font'
# wc = WordCloud(stopwords=STOPWORDS, font_path=font_path, 
#                background_color="white", max_words=2000,
#                max_font_size=256, random_state=42,
#                width=500, height=500)
# wc.generate(stripped_all)
# plt.imshow(wc, interpolation="bilinear")
# plt.axis('off')
# plt.show()

# %%
from PIL import Image
import numpy as np
