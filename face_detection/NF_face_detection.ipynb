# %%
! pip install CMake

# %%
# !pip install dlib

# %%
import cv2
import numpy as np
import dlib
import matplotlib.pyplot as plt
from PIL import Image
import os
#import time

# %% [markdown]
# # Get image from camera

# %%
## Connects to your computer's default camera
#cap = cv2.VideoCapture(0)
#print(type(cap))
#
#
## Detect the coordinates
#detector = dlib.get_frontal_face_detector()
#
#
## Capture frames continuously
#while True:
#
#    # Capture frame-by-frame
#    ret, frame = cap.read()
#    frame = cv2.flip(frame, 1)
#    # RGB to grayscale
#    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#    faces = detector(gray)
#    # Iterator to count faces
#    i = 0
#    for face in faces:
#
#        # Get the coordinates of faces
#        x, y = face.left(), face.top()
#        x1, y1 = face.right(), face.bottom()
#        cv2.rectangle(frame, (x, y), (x1, y1), (0, 255, 0), 2)
#        # Increment iterator for each face in faces
#        i = i+1
#        # Display the box and faces
#        cv2.putText(frame, 'face num'+str(i), (x-10, y-10),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
#        print(face, i)
#
#    # Display the resulting frame
#    #print(type(frame))
#    plt.imshow(frame)
#    # This command let's us quit with the "q" button on a keyboard.
#    if cv2.waitKey(1):# & 0xFF == ord('q'):
#        #print('stop')
#        break
#
#
## Release the capture and destroy the windows
#cap.release()
#cv2.destroyAllWindows()
#
# Out:
# <class 'cv2.VideoCapture'>
# [(93, 300) (217, 424)] 1
# [(373, 114) (552, 293)] 2

# %% [markdown]
# # Change to thumbnail input

# %%
# %%time
# Detect the coordinates
detector = dlib.get_frontal_face_detector()


# Capture thumbnail
img = Image.open('/Users/nicolafriedrich/code/jacksharples1/youtube_optimizer/bucket_data/thumbnail_images_0-RirLdUYEE_7032222')
frame = np.array(img)


frame = cv2.flip(frame, 1)
# RGB to grayscale
#gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
faces = detector(frame)
print("Number of faces detected: {}".format(len(faces)))
# Iterator to count faces
i = 0
for face in faces:
    # Get the coordinates of faces
    x, y = face.left(), face.top()
    x1, y1 = face.right(), face.bottom()
    cv2.rectangle(frame, (x, y), (x1, y1), (0, 255, 0), 2)
    # Increment iterator for each face in faces
    i = i+1
    # Display the box and faces
    cv2.putText(frame, 'face num'+str(i), (x-10, y-10),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    print(face, i)
# Display the resulting frame

#print(type(frame))
plt.imshow(frame)
# This command let's us quit with the "q" button on a keyboard.
cv2.waitKey(1)
# Rlease the capture and destroy the windows
cv2.destroyAllWindows()
# Out:
# Number of faces detected: 2
# [(229, 45) (301, 117)] 1
# [(21, 37) (93, 109)] 2
# CPU times: user 616 ms, sys: 16.7 ms, total: 633 ms
# Wall time: 706 ms

# %% [markdown]
# # Loop

# %%
from google.cloud import storage

# %%
def load_data_direct(bucket_name):
    bucket = storage.Client().get_bucket(bucket_name)
    face_dicts = []
    for blob in bucket.list_blobs(prefix = 'long_data(lunch4)'): 
        filename = blob.name.strip('long_data(lunch4)/')
        if len(filename)>0:
            img = cv2.imdecode(
                        np.asarray(bytearray(blob.download_as_string()), dtype=np.uint8), -1)
            num_faces = len(detector(img))
            if num_faces != 0:
                last_underscore = filename.rfind('_')
                video_id = filename[0:last_underscore]
                view_count = filename[last_underscore+1:]
                face_dict = {'video_id':video_id,'view_count':view_count,'num_faces':num_faces}
                face_dicts.append(face_dict)
            else:
                continue
        else:
            continue
    return face_dicts

# %%
# %%time
images = load_data_direct('nf_youtube')
images
# Out:
# CPU times: user 4min 38s, sys: 13.6 s, total: 4min 51s
# Wall time: 38min 31s
# [{'video_id': '--PJru8WQhw', 'view_count': '141612', 'num_faces': 1},
#  {'video_id': '-0GbqToowCw', 'view_count': '5657317', 'num_faces': 2},
#  {'video_id': '-6Kiyudi0oM', 'view_count': '1033505', 'num_faces': 2},
#  {'video_id': '-7ekQ7rr4pU', 'view_count': '3767858', 'num_faces': 2},
#  {'video_id': '-FKgblgN1JI', 'view_count': '599', 'num_faces': 1},
#  {'video_id': '-Ht4SrD1KPA', 'view_count': '14329035', 'num_faces': 1},
#  {'video_id': '-IbfjbhFocI', 'view_count': '653176', 'num_faces': 1},
#  {'video_id': '-IhgbNaeMoU', 'view_count': '3348947', 'num_faces': 1},
#  {'video_id': '-J8HskXNtaM', 'view_count': '953539', 'num_faces': 1},
#  {'video_id': '-LIMVVfRp6Q', 'view_count': '33674759', 'num_faces': 1},
#  {'video_id': '-M0jRaOOkT8', 'view_count': '324212', 'num_faces': 2},
#  {'video_id': '-NVIBd1dkk8', 'view_count': '14800', 'num_faces': 1},
#  {'video_id': '-Oh6ti7lh4g', 'view_count': '174713', 'num_faces': 2},
#  {'video_id': '-QQVnKd4Bjo', 'view_count': '3267563', 'num_faces': 1},
#  {'video_id': '-SONzSWFyVg', 'view_count': '11366', 'num_faces': 1},
#  {'video_id': '-SazWMwCFck', 'view_count': '13567', 'num_faces': 1},
#  {'video_id': '-VN-X8vlrTw', 'view_count': '2954907', 'num_faces': 1},
#  {'video_id': '-WEIIl5u8FE', 'view_count': '3999562', 'num_faces': 1},
#  {'video_id': '-XD8Dq8dWes', 'view_count': '5672', 'num_faces': 1},
#  {'video_id': '-YU58VSnzPY', 'view_count': '661796', 'num_faces': 3},
#  {'video_id': '-ZOUcsKMdmg', 'view_count': '32710', 'num_faces': 1},
#  {'video_id': '-ZnPFU9uQ8Y', 'view_count': '902111', 'num_faces': 1},
#  {'video_id': '-_W1Hk_M8JA', 'view_count': '63296', 'num_faces': 1},
#  {'video_id': '-_W1Hk_M8JA', 'view_count': '63298', 'num_faces': 1},
#  {'video_id': '-_cjIqcjBlw', 'view_count': '1681776', 'num_faces': 1},
#  {'video_id': '-asbs8dHAOk', 'view_count': '772997', 'num_faces': 1},
#  {'video_id': '-asbs8dHAOk', 'view_count': '773121', 'num_faces': 1},
#  {'video_id': '-bJQl4L6wLs', 'view_count': '6735502', 'num_faces': 1},
#  {'video_id': '-d3Mz1ON7aI', 'view_count': '90653', 'num_faces': 1},
#  {'video_id': '-eGKCjrWwUs', 'view_count': '21548', 'num_faces': 1},
#  {'video_id': '-eOSj-gsAf8', 'view_count': '680559', 'num_faces': 1},
#  {'video_id': '-eu5PFqYSBQ', 'view_count': '4110157', 'num_faces': 1},
#  {'video_id': '-hhfamsn83k', 'view_count': '36639349', 'num_faces': 1},
#  {'video_id': '-ice3DkzACA', 'view_count': '1017', 'num_faces': 1},
#  {'video_id': '-kJ24sEWx1c', 'view_count': '7', 'num_faces': 1},
#  {'video_id': '-mAETx6hH04', 'view_count': '52505', 'num_faces': 1},
#  {'video_id': '-mhm2ONUkh4', 'view_count': '1698288', 'num_faces': 1},
#  {'video_id': '-oNaLTjgfS4', 'view_count': '2572166', 'num_faces': 2},
#  {'video_id': '-qJJF6gjia8', 'view_count': '5147771', 'num_faces': 1},
#  {'video_id': '-qQSXmwzVKY', 'view_count': '159317', 'num_faces': 1},
#  {'video_id': '-vbraa31zNI', 'view_count': '124253', 'num_faces': 1},
#  {'video_id': '-xVycuXTEiI', 'view_count': '560167', 'num_faces': 2},
#  {'video_id': '-y5yuLuw7KQ', 'view_count': '1699269', 'num_faces': 1},
#  {'video_id': '0-s41PSmA-E', 'view_count': '472476', 'num_faces': 1},
#  {'video_id': '00FfLTC2NnE', 'view_count': '57298', 'num_faces': 1},
#  {'video_id': '00FfLTC2NnE', 'view_count': '57301', 'num_faces': 1},
#  {'video_id': '00FfLTC2NnE', 'view_count': '57306', 'num_faces': 1},
#  {'video_id': '00FfLTC2NnE', 'view_count': '57313', 'num_faces': 1},
#  {'video_id': '03d1_BvQk4Q', 'view_count': '9622145', 'num_faces': 1},
#  {'video_id': '05elVM0tQYE', 'view_count': '137571', 'num_faces': 1},
#  {'video_id': '05s8mLZE0fI', 'view_count': '4956392', 'num_faces': 1},
#  {'video_id': '05s8mLZE0fI', 'view_count': '4956410', 'num_faces': 1},
#  {'video_id': '06T6Gg8yDXs', 'view_count': '2769350', 'num_faces': 2},
#  {'video_id': '0Cj57sOhmEU', 'view_count': '3456271', 'num_faces': 1},
#  {'video_id': '0Dtb39OtRk0', 'view_count': '9826', 'num_faces': 1},
#  {'video_id': '0EjYIqPVQZk', 'view_count': '2110398', 'num_faces': 1},
#  {'video_id': '0FC0Y2cJhdM', 'view_count': '10246', 'num_faces': 1},
#  {'video_id': '0GW-ROqLRTI', 'view_count': '1552421', 'num_faces': 2},
#  {'video_id': '0HlREnMZ-gs', 'view_count': '138093', 'num_faces': 1},
#  {'video_id': '0IMuLA1Q5Jg', 'view_count': '22378101', 'num_faces': 1},
#  {'video_id': '0IbuI9sW65k', 'view_count': '783', 'num_faces': 1},
#  {'video_id': '0JfvU4pxsU0', 'view_count': '77586', 'num_faces': 3},
#  {'video_id': '0KI6ajrCBPE', 'view_count': '15693948', 'num_faces': 1},
#  {'video_id': '0NK-G60Jlb4', 'view_count': '36695', 'num_faces': 1},
#  {'video_id': '0Nw6r5GiGdM', 'view_count': '2159769', 'num_faces': 1},
#  {'video_id': '0Oif7iZcnAI', 'view_count': '58951588', 'num_faces': 1},
#  {'video_id': '0QXEqgcvS9I', 'view_count': '84252248', 'num_faces': 1},
#  {'video_id': '0QXEqgcvS9I', 'view_count': '84262868', 'num_faces': 1},
#  {'video_id': '0TdmKu_FMO0', 'view_count': '595', 'num_faces': 2},
#  {'video_id': '0Vp6_iwHqKQ', 'view_count': '2236107', 'num_faces': 1},
#  {'video_id': '0Z5bXuzNjUc', 'view_count': '83240', 'num_faces': 1},
#  {'video_id': '0Z9nRcKVmTY', 'view_count': '63370', 'num_faces': 1},
#  {'video_id': '0_2OW3SUYjc', 'view_count': '2247237', 'num_faces': 2},
#  {'video_id': '0aRIgVPB7q8', 'view_count': '1264176', 'num_faces': 1},
#  {'video_id': '0alpLpya7IE', 'view_count': '6040012', 'num_faces': 1},
#  {'video_id': '0alpLpya7IE', 'view_count': '6040153', 'num_faces': 1},
#  {'video_id': '0alpLpya7IE', 'view_count': '604067', 'num_faces': 1},
#  {'video_id': '0bk7vbKPdec', 'view_count': '1210667', 'num_faces': 1},
#  {'video_id': '0esl0vNINoY', 'view_count': '1312', 'num_faces': 1},
#  {'video_id': '0jATgRcNSMs', 'view_count': '137', 'num_faces': 1},
#  {'video_id': '0jp8F1uT8Qo', 'view_count': '51256', 'num_faces': 2},
#  {'video_id': '0klBazRudbI', 'view_count': '3621', 'num_faces': 1},
#  {'video_id': '0kvZDA4_cec', 'view_count': '40430', 'num_faces': 1},
#  {'video_id': '0nozIkMlYdE', 'view_count': '83269', 'num_faces': 1},
#  {'video_id': '0oWUt981fzw', 'view_count': '81', 'num_faces': 1},
#  {'video_id': '0p2-LB9-eSg', 'view_count': '253012', 'num_faces': 1},
#  {'video_id': '0pijvVVF0jc', 'view_count': '731', 'num_faces': 1},
#  {'video_id': '0ql8fLd68dk', 'view_count': '703459', 'num_faces': 1},
#  {'video_id': '0rCiNBsmDEk', 'view_count': '5098', 'num_faces': 1},
#  {'video_id': '0s0w4enH6D4', 'view_count': '66096601', 'num_faces': 1},
#  {'video_id': '0vaDigkAi2I', 'view_count': '3', 'num_faces': 1},
#  {'video_id': '0vbNLce7L-8', 'view_count': '124878', 'num_faces': 1},
#  {'video_id': '0vvScraE56Q', 'view_count': '11572', 'num_faces': 1},
#  {'video_id': '0wtbolg5NC4', 'view_count': '49149', 'num_faces': 3},
#  {'video_id': '0xHU7r6BgX4', 'view_count': '3488720', 'num_faces': 1},
#  {'video_id': '0y-P5iX6HQg', 'view_count': '882243', 'num_faces': 1},
#  {'video_id': '1-nBK_2BEEk', 'view_count': '1186979', 'num_faces': 1},
#  {'video_id': '1-nBK_2BEEk', 'view_count': '1187290', 'num_faces': 1},
#  {'video_id': '11kj-xdEgwE', 'view_count': '3639957', 'num_faces': 1},
#  {'video_id': '13I8Fyv8L34', 'view_count': '140333', 'num_faces': 1},
#  {'video_id': '15lJ31sKkcY', 'view_count': '1091975', 'num_faces': 1},
#  {'video_id': '17U3aagCtOA', 'view_count': '2897457', 'num_faces': 1},
#  {'video_id': '17U3aagCtOA', 'view_count': '289852', 'num_faces': 1},
#  {'video_id': '18s7uJe0M34', 'view_count': '3280621', 'num_faces': 1},
#  {'video_id': '1BAsjof56mY', 'view_count': '11145', 'num_faces': 1},
#  {'video_id': '1BqDIwn-15Y', 'view_count': '12167328', 'num_faces': 1},
#  {'video_id': '1CRlJ1j1bXY', 'view_count': '2706', 'num_faces': 1},
#  {'video_id': '1EhiAiOEFd0', 'view_count': '3712193', 'num_faces': 1},
#  {'video_id': '1EpK5GIR-cA', 'view_count': '1952058', 'num_faces': 1},
#  {'video_id': '1Jnx8ew_zic', 'view_count': '20844705', 'num_faces': 1},
#  {'video_id': '1Jnx8ew_zic', 'view_count': '20846463', 'num_faces': 1},
#  {'video_id': '1Kahk_ZKxEE', 'view_count': '20902', 'num_faces': 1},
#  {'video_id': '1MX_fSw8etY', 'view_count': '789430', 'num_faces': 1},
#  {'video_id': '1O6Jn43I2XQ', 'view_count': '541108', 'num_faces': 1},
#  {'video_id': '1O7-lZtzFQ0', 'view_count': '73688', 'num_faces': 1},
#  {'video_id': '1Oy1Cap-6pY', 'view_count': '149005', 'num_faces': 1},
#  {'video_id': '1QkU_VZdhNI', 'view_count': '188', 'num_faces': 1},
#  {'video_id': '1R-vxMPgYuI', 'view_count': '8603158', 'num_faces': 1},
#  {'video_id': '1R_K4rMkQBU', 'view_count': '352', 'num_faces': 1},
#  {'video_id': '1T-Mkj7xIsg', 'view_count': '1710746', 'num_faces': 1},
#  {'video_id': '1Tkj_ofsEaE', 'view_count': '481727', 'num_faces': 2},
#  {'video_id': '1V07vUnIEKk', 'view_count': '7442848', 'num_faces': 1},
#  {'video_id': '1V07vUnIEKk', 'view_count': '7442906', 'num_faces': 1},
#  {'video_id': '1VaoDZpzWTw', 'view_count': '312872', 'num_faces': 1},
#  {'video_id': '1VaoDZpzWTw', 'view_count': '312883', 'num_faces': 1},
#  {'video_id': '1VaoDZpzWTw', 'view_count': '31290', 'num_faces': 1},
#  {'video_id': '1XeFOJJS4JU', 'view_count': '13529729', 'num_faces': 1},
#  {'video_id': '1YgihesttPQ', 'view_count': '2292826', 'num_faces': 1},
#  {'video_id': '1as2dggORKQ', 'view_count': '36092', 'num_faces': 1},
#  {'video_id': '1bx8PbZIxj8', 'view_count': '1576328', 'num_faces': 1},
#  {'video_id': '1dHadpmXhxo', 'view_count': '432387', 'num_faces': 1},
#  {'video_id': '1h3q4DiwGgE', 'view_count': '3674531', 'num_faces': 1},
#  {'video_id': '1hlJvTUzA30', 'view_count': '1143381', 'num_faces': 2},
#  {'video_id': '1jR8Ho5aQl8', 'view_count': '7032612', 'num_faces': 1},
#  {'video_id': '1ki9pS_EwMw', 'view_count': '5927', 'num_faces': 2},
#  {'video_id': '1lXbSGMxMnc', 'view_count': '3324347', 'num_faces': 1},
#  {'video_id': '1lYVn31v-g8', 'view_count': '164576', 'num_faces': 1},
#  {'video_id': '1m7_l7_oP_k', 'view_count': '9087618', 'num_faces': 1},
#  {'video_id': '1niQkJkUc1A', 'view_count': '788569', 'num_faces': 2},
#  {'video_id': '1pZhsu5TZ-o', 'view_count': '144068', 'num_faces': 1},
#  {'video_id': '1xaogDmG-GE', 'view_count': '3072752', 'num_faces': 1},
#  {'video_id': '1yrokAiKfRI', 'view_count': '38', 'num_faces': 1},
#  {'video_id': '1z49OyCv6SM', 'view_count': '360863', 'num_faces': 1},
#  {'video_id': '2-WSNw7LCMc', 'view_count': '2833', 'num_faces': 1},
#  {'video_id': '203xQUTcs_g', 'view_count': '8727', 'num_faces': 1},
#  {'video_id': '22oqr6o5z-w', 'view_count': '672739', 'num_faces': 1},
#  {'video_id': '235lWT6XYkc', 'view_count': '589589', 'num_faces': 1},
#  {'video_id': '26kx8x4Bsl8', 'view_count': '5323', 'num_faces': 1},
#  {'video_id': '28arq4rdsuI', 'view_count': '3856745', 'num_faces': 1},
#  {'video_id': '2AMmmWsuIMw', 'view_count': '9162142', 'num_faces': 1},
#  {'video_id': '2AUD2WwYY_s', 'view_count': '35267', 'num_faces': 1},
#  {'video_id': '2C59SMeI1Ok', 'view_count': '9588', 'num_faces': 1},
#  {'video_id': '2EvzQ49FpB0', 'view_count': '617680', 'num_faces': 1},
#  {'video_id': '2IgjUYrDbWI', 'view_count': '35982', 'num_faces': 1},
#  {'video_id': '2P6l05N1tfY', 'view_count': '5', 'num_faces': 1},
#  {'video_id': '2PgY0vHkAko', 'view_count': '1001999', 'num_faces': 1},
#  {'video_id': '2QYZDZMl0MQ', 'view_count': '1452227', 'num_faces': 1},
#  {'video_id': '2T4YJ1skSrg', 'view_count': '102145', 'num_faces': 1},
#  {'video_id': '2UAYC7Li6Xo', 'view_count': '1451080', 'num_faces': 1},
#  {'video_id': '2UMUT5-tGTQ', 'view_count': '461360', 'num_faces': 1},
#  {'video_id': '2UNYuK9Xi1o', 'view_count': '22538202', 'num_faces': 1},
#  {'video_id': '2XKNr2mo_Fk', 'view_count': '16020', 'num_faces': 1},
#  {'video_id': '2awPPVKmpRQ', 'view_count': '1094728', 'num_faces': 1},
#  {'video_id': '2dP-OxMbukw', 'view_count': '9342080', 'num_faces': 1},
#  {'video_id': '2fevFc4ILy4', 'view_count': '2246758', 'num_faces': 1},
#  {'video_id': '2jYUhgMFZ1M', 'view_count': '6024153', 'num_faces': 1},
#  {'video_id': '2k-HBiyJvpM', 'view_count': '919736', 'num_faces': 1},
#  {'video_id': '2nC8IMmd8T4', 'view_count': '39', 'num_faces': 1},
#  {'video_id': '2qLZrrx16Dw', 'view_count': '491736', 'num_faces': 2},
#  {'video_id': '2rRdl3vMqPI', 'view_count': '904793', 'num_faces': 2},
#  {'video_id': '2s_VUcwKUJM', 'view_count': '1445901', 'num_faces': 1},
#  {'video_id': '2s_VUcwKUJM', 'view_count': '1445937', 'num_faces': 1},
#  {'video_id': '2sjA763puuU', 'view_count': '981168', 'num_faces': 1},
#  {'video_id': '3-ZKlNOonB8', 'view_count': '2101342', 'num_faces': 1},
#  {'video_id': '3-ZKlNOonB8', 'view_count': '2101605', 'num_faces': 1},
#  {'video_id': '313uorSD2oQ', 'view_count': '4365273', 'num_faces': 2},
#  {'video_id': '31HfjnVJG-Y', 'view_count': '1770388', 'num_faces': 1},
#  {'video_id': '36q5BS1PNpc', 'view_count': '375630', 'num_faces': 1},
#  {'video_id': '39_kXqPcTRQ', 'view_count': '721282', 'num_faces': 1},
#  {'video_id': '3EQgJPVL-zQ', 'view_count': '315307', 'num_faces': 1},
#  {'video_id': '3FhflecR_44', 'view_count': '1765259', 'num_faces': 1},
#  {'video_id': '3JOHHCtYIZg', 'view_count': '310977', 'num_faces': 1},
#  {'video_id': '3MFfbwiJrOc', 'view_count': '2254796', 'num_faces': 1},
#  {'video_id': '3N7HQBmPyyU', 'view_count': '127665', 'num_faces': 1},
#  {'video_id': '3Qy3f5qthfg', 'view_count': '636526', 'num_faces': 1},
#  {'video_id': '3R0AlwgcyDE', 'view_count': '7233922', 'num_faces': 1},
#  {'video_id': '3RhBw_i9RqU', 'view_count': '74675', 'num_faces': 2},
#  {'video_id': '3SAmHALgO58', 'view_count': '39998', 'num_faces': 1},
#  {'video_id': '3Sh06VUiXaA', 'view_count': '671901', 'num_faces': 1},
#  {'video_id': '3TZ-tHNKkPs', 'view_count': '59076', 'num_faces': 1},
#  {'video_id': '3WCE2QZ6qkc', 'view_count': '60887', 'num_faces': 1},
#  {'video_id': '3Wvhet4Yl-Y', 'view_count': '1330333', 'num_faces': 1},
#  {'video_id': '3a4YawbidY0', 'view_count': '480101', 'num_faces': 1},
#  {'video_id': '3cvTUgxpnGI', 'view_count': '17848326', 'num_faces': 1},
#  {'video_id': '3fY4wDllCzE', 'view_count': '70836', 'num_faces': 1},
#  {'video_id': '3g-_Q8dCuHA', 'view_count': '862867', 'num_faces': 1},
#  {'video_id': '3h03MO90niA', 'view_count': '1052300', 'num_faces': 2},
#  {'video_id': '3iZ9gqtouqA', 'view_count': '33218880', 'num_faces': 1},
#  {'video_id': '3kvD7y49PaI', 'view_count': '12256255', 'num_faces': 1},
#  {'video_id': '3kvD7y49PaI', 'view_count': '12256335', 'num_faces': 1},
#  {'video_id': '3kvD7y49PaI', 'view_count': '12256585', 'num_faces': 1},
#  {'video_id': '3kvD7y49PaI', 'view_count': '12257155', 'num_faces': 1},
#  {'video_id': '3l04R6SEtBY', 'view_count': '15534547', 'num_faces': 1},
#  {'video_id': '3m-wUX2IWY0', 'view_count': '168565', 'num_faces': 2},
#  {'video_id': '3quWFfC8WZs', 'view_count': '33707', 'num_faces': 1},
#  {'video_id': '3sEJo059WPQ', 'view_count': '436', 'num_faces': 1},
#  {'video_id': '3sKfA6YRuPw', 'view_count': '3074767', 'num_faces': 1},
#  {'video_id': '3yvVjrVpzws', 'view_count': '1419912', 'num_faces': 2},
#  {'video_id': '3z52WLEB0y4', 'view_count': '435718', 'num_faces': 1},
#  {'video_id': '2VlLJ5fcpo', 'view_count': '115765919', 'num_faces': 1},
#  {'video_id': '2tieTKUn4w', 'view_count': '3506', 'num_faces': 1},
#  {'video_id': 'EfmSdrX0w', 'view_count': '2961869', 'num_faces': 1},
#  {'video_id': '6qYBV5Rsbk', 'view_count': '1609', 'num_faces': 1},
#  {'video_id': '7MNn4bsmSw', 'view_count': '75516002', 'num_faces': 1},
#  {'video_id': '8TIDFj6U_Y', 'view_count': '2938397', 'num_faces': 1},
#  {'video_id': '8YwaTiYau0', 'view_count': '240890', 'num_faces': 1},
#  {'video_id': '90VZc2xoXY', 'view_count': '45036', 'num_faces': 2},
#  {'video_id': '93NigyHWBg', 'view_count': '107858736', 'num_faces': 1},
#  {'video_id': 'AzpmZ7AjaQ', 'view_count': '930535', 'num_faces': 1},
#  {'video_id': 'CgLInSuNw4', 'view_count': '32715', 'num_faces': 1},
#  {'video_id': 'EzJWcuDLvc', 'view_count': '54192', 'num_faces': 1},
#  {'video_id': 'IDEyfujd8k', 'view_count': '1100479', 'num_faces': 2},
#  {'video_id': 'K8hNS3jmiQ', 'view_count': '18419', 'num_faces': 1},
#  {'video_id': 'Lrx6-amXx0', 'view_count': '176855', 'num_faces': 1},
#  {'video_id': 'OG58_nGU88', 'view_count': '3505755', 'num_faces': 1},
#  {'video_id': 'OG58_nGU88', 'view_count': '3506063', 'num_faces': 1},
#  {'video_id': 'SdoAq69UDc', 'view_count': '19', 'num_faces': 1},
#  {'video_id': 'UeefWkuj1s', 'view_count': '35026', 'num_faces': 1},
#  {'video_id': 'VIp9VcYllc', 'view_count': '34965742', 'num_faces': 1},
#  {'video_id': 'ViqdOMAPOk', 'view_count': '11741492', 'num_faces': 1},
#  {'video_id': 'ViqdOMAPOk', 'view_count': '11741581', 'num_faces': 1},
#  {'video_id': 'ViqdOMAPOk', 'view_count': '11742135', 'num_faces': 1},
#  {'video_id': 'ViqdOMAPOk', 'view_count': '11742255', 'num_faces': 1},
#  {'video_id': 'pgpphluD0', 'view_count': '6591787', 'num_faces': 1},
#  {'video_id': 'J_YmhL62Y', 'view_count': '2133779', 'num_faces': 1},
#  {'video_id': 'yGpcGoF8', 'view_count': '108450', 'num_faces': 2},
#  {'video_id': 'eQdBXVdnZg', 'view_count': '660023', 'num_faces': 1},
#  {'video_id': 'eRcNyF0MYQ', 'view_count': '3511650', 'num_faces': 1},
#  {'video_id': 'jpR6XVZwM', 'view_count': '1915', 'num_faces': 2},
#  {'video_id': 'i6rRdgVEi0', 'view_count': '16464218', 'num_faces': 2},
#  {'video_id': 'jH4wRhKKs8', 'view_count': '229955', 'num_faces': 2},
#  {'video_id': 'K6-agsPaY', 'view_count': '65842', 'num_faces': 1},
#  {'video_id': 'qGcqjdcoFc', 'view_count': '9552658', 'num_faces': 1},
#  {'video_id': 'qZK7PvqXJY', 'view_count': '8679', 'num_faces': 1},
#  {'video_id': 'k2SEV1ZJk', 'view_count': '7318', 'num_faces': 2},
#  {'video_id': 'G5X5zblk', 'view_count': '388569', 'num_faces': 2},
#  {'video_id': 'qjHQwCuzs', 'view_count': '9294432', 'num_faces': 1},
#  {'video_id': 'vV4pUzVuA', 'view_count': '590030', 'num_faces': 1},
#  {'video_id': 'veye2V_2VQ', 'view_count': '5405', 'num_faces': 1},
#  {'video_id': 'vuaB0NdYho', 'view_count': '783742', 'num_faces': 1},
#  {'video_id': 'xc4TERZR8w', 'view_count': '10988222', 'num_faces': 1},
#  {'video_id': 'zE6GtYJUtI', 'view_count': '3397187', 'num_faces': 1},
#  {'video_id': '5-_8nSrrf2w', 'view_count': '27', 'num_faces': 1},
#  {'video_id': '500MmsPmx3o', 'view_count': '1145658', 'num_faces': 1},
#  {'video_id': '50sTkRJvcCo', 'view_count': '772647', 'num_faces': 1},
#  {'video_id': '53XwJEevaLs', 'view_count': '27897', 'num_faces': 1},
#  {'video_id': '54BWxOWJu7Q', 'view_count': '62', 'num_faces': 1},
#  {'video_id': '57-rHfjdoV8', 'view_count': '2441126', 'num_faces': 1},
#  {'video_id': '57zKhk9liFg', 'view_count': '100246', 'num_faces': 1},
#  {'video_id': '58V-as53_fY', 'view_count': '11', 'num_faces': 1},
#  {'video_id': '58r5gpf0e-c', 'view_count': '190799', 'num_faces': 1},
#  {'video_id': '58zd7C2CzOs', 'view_count': '78198', 'num_faces': 1},
#  {'video_id': '592vGKJKu4Q', 'view_count': '1115650', 'num_faces': 1},
#  {'video_id': '5EaQxnXM9SY', 'view_count': '593113', 'num_faces': 1},
#  {'video_id': '5G68RRogrEI', 'view_count': '1278421', 'num_faces': 1},
#  {'video_id': '5HNmp6vxsnM', 'view_count': '224488', 'num_faces': 1},
#  {'video_id': '5Higt8U_hDI', 'view_count': '859', 'num_faces': 1},
#  {'video_id': '5Ke3bXylxLw', 'view_count': '1886', 'num_faces': 1},
#  {'video_id': '5LxMqrKQW-E', 'view_count': '911021', 'num_faces': 1},
#  {'video_id': '5Szjemb24QA', 'view_count': '62476', 'num_faces': 2},
#  {'video_id': '5Tp9b0rS_z4', 'view_count': '1721047', 'num_faces': 1},
#  {'video_id': '5X83995pWFw', 'view_count': '2127718', 'num_faces': 1},
#  {'video_id': '5e9jUaxGr8U', 'view_count': '1786792', 'num_faces': 1},
#  {'video_id': '5eZhwEnV8z8', 'view_count': '246968', 'num_faces': 1},
#  {'video_id': '5wlAnIowbXw', 'view_count': '97887', 'num_faces': 1},
#  {'video_id': '5xwSubYz9yU', 'view_count': '1422439', 'num_faces': 1},
#  {'video_id': '5ylcS6bzJN0', 'view_count': '42190', 'num_faces': 1},
#  {'video_id': '5yp95NQ_wss', 'view_count': '763577', 'num_faces': 1},
#  {'video_id': '5zVK5-ikw_Y', 'view_count': '115149', 'num_faces': 1},
#  {'video_id': '6-uk66ko1Nw', 'view_count': '1132775', 'num_faces': 1},
#  {'video_id': '63t8iW07zUc', 'view_count': '1232551', 'num_faces': 1},
#  {'video_id': '6G8Q9BhjaGw', 'view_count': '2590382', 'num_faces': 2},
#  {'video_id': '6JahBrsgU6s', 'view_count': '1667', 'num_faces': 1},
#  {'video_id': '6Jn7IjTC6_8', 'view_count': '54606', 'num_faces': 1},
#  {'video_id': '6KZ9Vu9A7r8', 'view_count': '2083419', 'num_faces': 1},
#  {'video_id': '6LS4oKobHp0', 'view_count': '75297', 'num_faces': 1},
#  {'video_id': '6MsZXZjJGLY', 'view_count': '210790', 'num_faces': 1},
#  {'video_id': '6N8NF0yhdgI', 'view_count': '401312', 'num_faces': 1},
#  {'video_id': '6NhTIx7QuzQ', 'view_count': '71051', 'num_faces': 2},
#  {'video_id': '6OHyL_OPZMQ', 'view_count': '13443', 'num_faces': 1},
#  {'video_id': '6R6zKtMvPBg', 'view_count': '358237', 'num_faces': 1},
#  {'video_id': '6VLmlnyp3ls', 'view_count': '29399', 'num_faces': 2},
#  {'video_id': '6WDPU9T_6T8', 'view_count': '2274915', 'num_faces': 1},
#  {'video_id': '6Zbb33o0qCo', 'view_count': '188816', 'num_faces': 1},
#  {'video_id': '6Zbb33o0qCo', 'view_count': '188827', 'num_faces': 1},
#  {'video_id': '6aAto3KmFOY', 'view_count': '156', 'num_faces': 1},
#  {'video_id': '6caTg2Xovlg', 'view_count': '578617', 'num_faces': 1},
#  {'video_id': '6cbLgXAuLsU', 'view_count': '30855081', 'num_faces': 1},
#  {'video_id': '6csEFbYK8_g', 'view_count': '130731', 'num_faces': 1},
#  {'video_id': '6eHPvweslFM', 'view_count': '8665432', 'num_faces': 1},
#  {'video_id': '6fKY5TaiakM', 'view_count': '158353', 'num_faces': 1},
#  {'video_id': '6gMwZySoOdM', 'view_count': '20003', 'num_faces': 1},
#  {'video_id': '6htUWjH1Qd0', 'view_count': '70070', 'num_faces': 1},
#  {'video_id': '6htUWjH1Qd0', 'view_count': '70071', 'num_faces': 1},
#  {'video_id': '6ikI43TnXoM', 'view_count': '99698', 'num_faces': 1},
#  {'video_id': '6jnvF04Br_Y', 'view_count': '56020', 'num_faces': 2},
#  {'video_id': '6jtZw_VoOno', 'view_count': '307398', 'num_faces': 1},
#  {'video_id': '6lFFzdFslzo', 'view_count': '9423805', 'num_faces': 1},
#  {'video_id': '6mrNxb2Po2Y', 'view_count': '1302201', 'num_faces': 1},
#  {'video_id': '6n5ypoq6Dm4', 'view_count': '2100530', 'num_faces': 1},
#  {'video_id': '6ox34qr8KDE', 'view_count': '1025', 'num_faces': 1},
#  {'video_id': '6tykZMNHnak', 'view_count': '114185', 'num_faces': 1},
#  {'video_id': '6vEydz6KQ7E', 'view_count': '27', 'num_faces': 1},
#  {'video_id': '6vswP7VhkMA', 'view_count': '7464005', 'num_faces': 1},
#  {'video_id': '6wyirNSXmUQ', 'view_count': '937488', 'num_faces': 1},
#  {'video_id': '6yRxuqfECrI', 'view_count': '220028', 'num_faces': 1},
#  {'video_id': '6yU5SlQD33o', 'view_count': '1137667', 'num_faces': 1},
#  {'video_id': '7-PnbvIOPsk', 'view_count': '656080', 'num_faces': 1},
#  {'video_id': '7-PnbvIOPsk', 'view_count': '656091', 'num_faces': 1},
#  {'video_id': '745OaH0gUOY', 'view_count': '5070', 'num_faces': 1},
#  {'video_id': '75KlD3onWRs', 'view_count': '11', 'num_faces': 1},
#  {'video_id': '75v8Vo_xQ4U', 'view_count': '9327', 'num_faces': 1},
#  {'video_id': '76hxGsXN2EI', 'view_count': '473471', 'num_faces': 1},
#  {'video_id': '76ls-EtQSMM', 'view_count': '276571', 'num_faces': 1},
#  {'video_id': '77il-5zAqyE', 'view_count': '1551966', 'num_faces': 1},
#  {'video_id': '78m999_j2HM', 'view_count': '675158', 'num_faces': 1},
#  {'video_id': '78m999_j2HM', 'view_count': '675261', 'num_faces': 1},
#  {'video_id': '7Dmy16fInUE', 'view_count': '2544457', 'num_faces': 1},
#  {'video_id': '7FugYxuW2F0', 'view_count': '8451902', 'num_faces': 1},
#  {'video_id': '7HpVp9nuDOk', 'view_count': '20922', 'num_faces': 1},
#  {'video_id': '7ImFp1OxKAw', 'view_count': '39291', 'num_faces': 1},
#  {'video_id': '7NEhXw1s_30', 'view_count': '292', 'num_faces': 1},
#  {'video_id': '7QIP_r139JE', 'view_count': '68763', 'num_faces': 1},
#  {'video_id': '7R95lwxYZcI', 'view_count': '569227', 'num_faces': 1},
#  {'video_id': '7RF5YIsBriY', 'view_count': '506528', 'num_faces': 1},
#  {'video_id': '7S810fj_5kw', 'view_count': '357', 'num_faces': 1},
#  {'video_id': '7T6vbLmluxk', 'view_count': '957249', 'num_faces': 1},
#  {'video_id': '7TKOzR-z0RI', 'view_count': '1271536', 'num_faces': 2},
#  {'video_id': '7XGg_BtkhEQ', 'view_count': '11830403', 'num_faces': 1},
#  {'video_id': '7XX9d4wRqy0', 'view_count': '215143', 'num_faces': 1},
#  {'video_id': '7ZplAYjIVS8', 'view_count': '3972', 'num_faces': 1},
#  {'video_id': '7ZpzinbVzz0', 'view_count': '8788668', 'num_faces': 1},
#  {'video_id': '7_724_kXGvg', 'view_count': '8624911', 'num_faces': 1},
#  {'video_id': '7_I8Ep9EvHI', 'view_count': '33925', 'num_faces': 1},
#  {'video_id': '7al5CjjPw4o', 'view_count': '9093', 'num_faces': 1},
#  {'video_id': '7gIauXMFLjs', 'view_count': '1633408', 'num_faces': 2},
#  {'video_id': '7hDyEssq92U', 'view_count': '394700', 'num_faces': 1},
#  {'video_id': '7hDyEssq92U', 'view_count': '394798', 'num_faces': 1},
#  {'video_id': '7iVOUAE8Mvg', 'view_count': '256775', 'num_faces': 1},
#  {'video_id': '7kv_iK7Zgsw', 'view_count': '39152', 'num_faces': 1},
#  {'video_id': '7l6L5wFfsLU', 'view_count': '9576868', 'num_faces': 1},
#  {'video_id': '7mVWYCZiUZY', 'view_count': '496542', 'num_faces': 1},
#  {'video_id': '7n6PFfK2LFM', 'view_count': '467780', 'num_faces': 2},
#  {'video_id': '7o9loaY8NbM', 'view_count': '16', 'num_faces': 1},
#  {'video_id': '7p9wFVcFRH8', 'view_count': '77876', 'num_faces': 1},
#  {'video_id': '7y6NmSKKfIk', 'view_count': '440818', 'num_faces': 1},
#  {'video_id': '7ziWrneMYss', 'view_count': '12358938', 'num_faces': 1},
#  {'video_id': '8-_FSOptE7U', 'view_count': '43863', 'num_faces': 2},
#  {'video_id': '8-gtURFmiGg', 'view_count': '3889450', 'num_faces': 2},
#  {'video_id': '828uSsmktMI', 'view_count': '9683872', 'num_faces': 1},
#  {'video_id': '82FhLW1VI6Y', 'view_count': '149739', 'num_faces': 1},
#  {'video_id': '83V0SD4gN8k', 'view_count': '35395', 'num_faces': 1},
#  {'video_id': '8447W0D36zw', 'view_count': '3', 'num_faces': 1},
#  {'video_id': '84wTkWxXkrs', 'view_count': '1651', 'num_faces': 2},
#  {'video_id': '864K8cpSBAE', 'view_count': '758747', 'num_faces': 1},
#  {'video_id': '8EoBNzgN2AU', 'view_count': '3455769', 'num_faces': 1},
#  {'video_id': '8F23Jyf_a24', 'view_count': '549188', 'num_faces': 1},
#  {'video_id': '8GxCRoLNsL4', 'view_count': '2880', 'num_faces': 1},
#  {'video_id': '8JMKnNMcfQ8', 'view_count': '204068', 'num_faces': 1},
#  {'video_id': '8K74dDaSq1U', 'view_count': '77', 'num_faces': 1},
#  {'video_id': '8N9F-Xj7n4Y', 'view_count': '67', 'num_faces': 1},
#  {'video_id': '8OfiPZFB4FQ', 'view_count': '5486039', 'num_faces': 1},
#  {'video_id': '8Rp-K_DfZl8', 'view_count': '4718859', 'num_faces': 1},
#  {'video_id': '8Rp-K_DfZl8', 'view_count': '4719138', 'num_faces': 1},
#  {'video_id': '8S-b-bixOeo', 'view_count': '36666', 'num_faces': 1},
#  {'video_id': '8VatAE1Uq5U', 'view_count': '5189', 'num_faces': 2},
#  {'video_id': '8WlJTAM3P_g', 'view_count': '399462', 'num_faces': 1},
#  {'video_id': '8WrMirXxinM', 'view_count': '1201765', 'num_faces': 1},
#  {'video_id': '8YxjwoBaGhE', 'view_count': '9056', 'num_faces': 1},
#  {'video_id': '8ZtSzcJlIaM', 'view_count': '35', 'num_faces': 2},
#  {'video_id': '8_-bUIX1hDs', 'view_count': '441265', 'num_faces': 1},
#  {'video_id': '8_679XlXfLM', 'view_count': '1641', 'num_faces': 1},
#  {'video_id': '8cJceckE1yc', 'view_count': '663', 'num_faces': 1},
#  {'video_id': '8dmWOwGY-WM', 'view_count': '12510', 'num_faces': 1},
#  {'video_id': '8eOj3Adnq2c', 'view_count': '1532', 'num_faces': 1},
#  {'video_id': '8gQiiKaTkVc', 'view_count': '987293', 'num_faces': 1},
#  {'video_id': '8lsFr0XmBvo', 'view_count': '180237', 'num_faces': 1},
#  {'video_id': '8m3Yb1UEOp8', 'view_count': '13037185', 'num_faces': 1},
#  {'video_id': '8nToKmFwmPw', 'view_count': '4115713', 'num_faces': 1},
#  {'video_id': '8r0_drIaQtM', 'view_count': '815458', 'num_faces': 1},
#  {'video_id': '8r2LGkuWDkE', 'view_count': '65189', 'num_faces': 1},
#  {'video_id': '8tlb0F1MFP0', 'view_count': '948509', 'num_faces': 1},
#  {'video_id': '8tx82Rg6w70', 'view_count': '240161', 'num_faces': 1},
#  {'video_id': '8wBMPL1hXpk', 'view_count': '38', 'num_faces': 1},
#  {'video_id': '8wm14Yj_EQA', 'view_count': '522402', 'num_faces': 1},
#  {'video_id': '8wnNABO1yTA', 'view_count': '306070', 'num_faces': 1},
#  {'video_id': '8y5qEud6y6Q', 'view_count': '1568740', 'num_faces': 1},
#  {'video_id': '8yDa7nz1tjE', 'view_count': '810', 'num_faces': 1},
#  {'video_id': '93zk6Jz9HYI', 'view_count': '1361', 'num_faces': 1},
#  {'video_id': '952GXgS2f0Q', 'view_count': '11668', 'num_faces': 1},
#  {'video_id': '957KcdowAXA', 'view_count': '2788488', 'num_faces': 2},
#  {'video_id': '95ABSqRpy74', 'view_count': '821312', 'num_faces': 1},
#  {'video_id': '982kFZ2LrDk', 'view_count': '81187', 'num_faces': 1},
#  {'video_id': '9AUyYcznb98', 'view_count': '57136769', 'num_faces': 1},
#  {'video_id': '9AvAKYLTc-c', 'view_count': '12653', 'num_faces': 1},
#  {'video_id': '9BTB-WqjFfo', 'view_count': '1546457', 'num_faces': 1},
#  {'video_id': '9BTB-WqjFfo', 'view_count': '1546459', 'num_faces': 1},
#  {'video_id': '9Gfnunv86LE', 'view_count': '53789', 'num_faces': 2},
#  {'video_id': '9IIFvpFilU4', 'view_count': '334726', 'num_faces': 1},
#  {'video_id': '9K2cjmKvnTE', 'view_count': '408513', 'num_faces': 1},
#  {'video_id': '9LsS0PHnmas', 'view_count': '3590', 'num_faces': 1},
#  {'video_id': '9NQ7aefti3U', 'view_count': '517357', 'num_faces': 2},
#  {'video_id': '9O-mclr2s_0', 'view_count': '1319', 'num_faces': 1},
#  {'video_id': '9VL_gDv7LXM', 'view_count': '1525693', 'num_faces': 1},
#  {'video_id': '9VmGAnDCgEk', 'view_count': '75637', 'num_faces': 1},
#  {'video_id': '9WAOiZfcIAc', 'view_count': '1451', 'num_faces': 1},
#  {'video_id': '9XeiFJ0NpPk', 'view_count': '11781', 'num_faces': 1},
#  {'video_id': '9gPBVdNhfCI', 'view_count': '1586536', 'num_faces': 1},
#  {'video_id': '9gbIN58SiCI', 'view_count': '282226', 'num_faces': 1},
#  {'video_id': '9j-YD11LcLw', 'view_count': '1818613', 'num_faces': 1},
#  {'video_id': '9j-YD11LcLw', 'view_count': '1818700', 'num_faces': 1},
#  {'video_id': '9jbVxKUPw_k', 'view_count': '6430053', 'num_faces': 1},
#  {'video_id': '9mZbKRwFr7E', 'view_count': '15692', 'num_faces': 1},
#  {'video_id': '9max8iVcejc', 'view_count': '122228', 'num_faces': 1},
#  {'video_id': '9mmAdMgJhx4', 'view_count': '13262', 'num_faces': 1},
#  {'video_id': '9n7mK-783I0', 'view_count': '79557', 'num_faces': 1},
#  {'video_id': '9p11LM2YLtM', 'view_count': '684125', 'num_faces': 1},
#  {'video_id': '9qRxNYuR2c4', 'view_count': '13291310', 'num_faces': 1},
#  {'video_id': '9xNcHeGJeLU', 'view_count': '3214008', 'num_faces': 1},
#  {'video_id': '9y-N2n5GFHA', 'view_count': '32', 'num_faces': 1},
#  {'video_id': 'A3GGXukkH6Y', 'view_count': '367460', 'num_faces': 1},
#  {'video_id': 'A5xsjCf2tRw', 'view_count': '400798', 'num_faces': 1},
#  {'video_id': 'AAzqVqxqh9Q', 'view_count': '913', 'num_faces': 1},
#  {'video_id': 'AB68mL3BPRw', 'view_count': '483390', 'num_faces': 1},
#  {'video_id': 'ABp-FzikuAM', 'view_count': '19379', 'num_faces': 2},
#  {'video_id': 'ACkIUNlm6w4', 'view_count': '33122', 'num_faces': 1},
#  {'video_id': 'AEgOuTaB264', 'view_count': '384613', 'num_faces': 1},
#  {'video_id': 'AFWVrM06Pw8', 'view_count': '313263', 'num_faces': 1},
#  {'video_id': 'AFeOITOVv5g', 'view_count': '147987', 'num_faces': 1},
#  {'video_id': 'AFq1Pto5h1Y', 'view_count': '54513715', 'num_faces': 1},
#  {'video_id': 'AG1p_6cJfaY', 'view_count': '9415617', 'num_faces': 1},
#  {'video_id': 'AGBizwLIZR8', 'view_count': '4473425', 'num_faces': 1},
#  {'video_id': 'AO-XP5qBlbw', 'view_count': '20726859', 'num_faces': 1},
#  {'video_id': 'APbyS6wUJ7M', 'view_count': '2105776', 'num_faces': 1},
#  {'video_id': 'ATbYs29wk-E', 'view_count': '347538', 'num_faces': 1},
#  {'video_id': 'AV5LAjUfFN4', 'view_count': '8946', 'num_faces': 1},
#  {'video_id': 'AVY6V9Tqtck', 'view_count': '27460', 'num_faces': 2},
#  {'video_id': 'AWzk_nURvCc', 'view_count': '519935', 'num_faces': 1},
#  {'video_id': 'AX03kPzaMCM', 'view_count': '1135066', 'num_faces': 1},
#  {'video_id': 'AYBmLykf6fY', 'view_count': '3709208', 'num_faces': 1},
#  {'video_id': 'AYmek9MPSoI', 'view_count': '69596', 'num_faces': 1},
#  {'video_id': 'AYnFiCRjnpY', 'view_count': '1040825', 'num_faces': 2},
#  {'video_id': 'AYnFiCRjnpY', 'view_count': '104085', 'num_faces': 2},
#  {'video_id': 'AYnFiCRjnpY', 'view_count': '1041066', 'num_faces': 2},
#  {'video_id': 'AaStwiGQ1Fc', 'view_count': '21920', 'num_faces': 1},
#  {'video_id': 'Abxx8qmKATw', 'view_count': '321', 'num_faces': 1},
#  {'video_id': 'AeNW1duZweA', 'view_count': '360588', 'num_faces': 1},
#  {'video_id': 'AfG43b2hi0c', 'view_count': '2020989', 'num_faces': 1},
#  {'video_id': 'AfqYSEaYFn0', 'view_count': '2353366', 'num_faces': 1},
#  {'video_id': 'Ai6XYtpT0hQ', 'view_count': '2726052', 'num_faces': 1},
#  {'video_id': 'AiSTp9qQS-o', 'view_count': '20', 'num_faces': 1},
#  {'video_id': 'AjL_3TDKEiM', 'view_count': '3415755', 'num_faces': 1},
#  {'video_id': 'AjL_3TDKEiM', 'view_count': '3415975', 'num_faces': 1},
#  {'video_id': 'An8Fa6Xaf9Q', 'view_count': '985251', 'num_faces': 1},
#  {'video_id': 'AnQ9phtPzt4', 'view_count': '109607', 'num_faces': 1},
#  {'video_id': 'AndRVDR10fE', 'view_count': '68582', 'num_faces': 1},
#  {'video_id': 'AojLXMDgagE', 'view_count': '885', 'num_faces': 1},
#  {'video_id': 'ApJksYE4JwM', 'view_count': '6053', 'num_faces': 1},
#  {'video_id': 'AuIKNIA1inc', 'view_count': '80652', 'num_faces': 1},
#  {'video_id': 'AvhfHPiq4sg', 'view_count': '609403', 'num_faces': 1},
#  {'video_id': 'AzOFmcl_26k', 'view_count': '84301', 'num_faces': 1},
#  {'video_id': 'B3uv9tmDwjU', 'view_count': '14234699', 'num_faces': 1},
#  {'video_id': 'B3w4pE_WrOg', 'view_count': '6076389', 'num_faces': 1},
#  {'video_id': 'B5WUhJUog_M', 'view_count': '21309743', 'num_faces': 1},
#  {'video_id': 'B8QfiokRLks', 'view_count': '9841', 'num_faces': 1},
#  {'video_id': 'BBbslcaJLA0', 'view_count': '2205157', 'num_faces': 2},
#  {'video_id': 'BC1wAQFJJBM', 'view_count': '30741993', 'num_faces': 1},
#  {'video_id': 'BC1wAQFJJBM', 'view_count': '30742005', 'num_faces': 1},
#  {'video_id': 'BC1wAQFJJBM', 'view_count': '30742019', 'num_faces': 1},
#  {'video_id': 'BC1wAQFJJBM', 'view_count': '30742040', 'num_faces': 1},
#  {'video_id': 'BCD9W_eLI6A', 'view_count': '13095460', 'num_faces': 1},
#  {'video_id': 'BCaWowGIy00', 'view_count': '8075150', 'num_faces': 1},
#  {'video_id': 'BDbBia1GwUM', 'view_count': '3960965', 'num_faces': 1},
#  {'video_id': 'BFYruyJUdYA', 'view_count': '4164957', 'num_faces': 1},
#  {'video_id': 'BGaRq5vi-gA', 'view_count': '298600', 'num_faces': 1},
#  {'video_id': 'BHEL2POlz7M', 'view_count': '1153561', 'num_faces': 1},
#  {'video_id': 'BHaeIxxs-Ps', 'view_count': '6356', 'num_faces': 1},
#  {'video_id': 'BJgQIjz_nrQ', 'view_count': '825878', 'num_faces': 1},
#  {'video_id': 'BLV7vvn8u8E', 'view_count': '534472', 'num_faces': 1},
#  {'video_id': 'BM9hMEEIQCo', 'view_count': '5668430', 'num_faces': 1},
#  {'video_id': 'BQGD_1eIj1s', 'view_count': '187376', 'num_faces': 1},
#  {'video_id': 'BS4ap1mZoBg', 'view_count': '899432', 'num_faces': 1},
#  {'video_id': 'BSFfEMxfO9A', 'view_count': '244812', 'num_faces': 1},
#  {'video_id': 'BSFfEMxfO9A', 'view_count': '2448236', 'num_faces': 1},
#  {'video_id': 'BSFfEMxfO9A', 'view_count': '2449537', 'num_faces': 1},
#  {'video_id': 'BUV5ENyCZ50', 'view_count': '7915', 'num_faces': 1},
#  {'video_id': 'BVTxeUYyrvA', 'view_count': '33987', 'num_faces': 1},
#  {'video_id': 'BVd1uSjU_Ss', 'view_count': '7536147', 'num_faces': 1},
#  {'video_id': 'BWz8S0qmiY0', 'view_count': '24250223', 'num_faces': 1},
#  {'video_id': 'B_-Uyc4spGM', 'view_count': '49183', 'num_faces': 1},
#  {'video_id': 'Ber5TpaJtEg', 'view_count': '4493069', 'num_faces': 1},
#  {'video_id': 'Bf6iV3Wtl4I', 'view_count': '835279', 'num_faces': 1},
#  {'video_id': 'BhE49SevmCA', 'view_count': '30289', 'num_faces': 1},
#  {'video_id': 'BiGg2cManzc', 'view_count': '397082', 'num_faces': 2},
#  {'video_id': 'BiGg2cManzc', 'view_count': '397103', 'num_faces': 2},
#  {'video_id': 'BjGbE3Ty_YA', 'view_count': '23148', 'num_faces': 1},
#  {'video_id': 'BpLOcJvZun0', 'view_count': '13489', 'num_faces': 1},
#  {'video_id': 'Bsj_PLth0pk', 'view_count': '10659', 'num_faces': 1},
#  {'video_id': 'Btvrxo4_tOU', 'view_count': '3175483', 'num_faces': 1},
#  {'video_id': 'Btvrxo4_tOU', 'view_count': '3176241', 'num_faces': 1},
#  {'video_id': 'ByS8epqnJcQ', 'view_count': '18783', 'num_faces': 1},
#  {'video_id': 'C-BNMejE8ro', 'view_count': '990677', 'num_faces': 1},
#  {'video_id': 'C12x2F0ZiIY', 'view_count': '837308', 'num_faces': 1},
#  {'video_id': 'C1hdaPp8uxk', 'view_count': '53851', 'num_faces': 1},
#  {'video_id': 'C2k3esJHFuE', 'view_count': '829926', 'num_faces': 1},
#  {'video_id': 'C50i7L5JKqQ', 'view_count': '169571', 'num_faces': 2},
#  {'video_id': 'C51z9Zulp8o', 'view_count': '743620', 'num_faces': 1},
#  {'video_id': 'CGqW0D2oDic', 'view_count': '769813', 'num_faces': 1},
#  {'video_id': 'CK78QUMcZL8', 'view_count': '36394163', 'num_faces': 1},
#  {'video_id': 'CLttvYGPRL4', 'view_count': '1388190', 'num_faces': 1},
#  {'video_id': 'CP31KP_J9_w', 'view_count': '1032102', 'num_faces': 1},
#  {'video_id': 'CP33VFbrB5o', 'view_count': '6915', 'num_faces': 1},
#  {'video_id': 'CS5YmRlF7qU', 'view_count': '409199', 'num_faces': 1},
#  {'video_id': 'CTeIMIOsh8g', 'view_count': '831757', 'num_faces': 1},
#  {'video_id': 'CUPBU_mJUtA', 'view_count': '2355952', 'num_faces': 1},
#  {'video_id': 'CVEydXHzZG4', 'view_count': '618127', 'num_faces': 1},
#  {'video_id': 'CVT_Z5I3Pm8', 'view_count': '15170397', 'num_faces': 1},
#  {'video_id': 'CVT_Z5I3Pm8', 'view_count': '1517058', 'num_faces': 1},
#  {'video_id': 'CVuoyn5vgyY', 'view_count': '12969', 'num_faces': 1},
#  {'video_id': 'CWVZJF1AQEA', 'view_count': '367785', 'num_faces': 1},
#  {'video_id': 'C_roCRDNcsA', 'view_count': '146971', 'num_faces': 1},
#  {'video_id': 'Ca9BgpHFKu4', 'view_count': '3395', 'num_faces': 1},
#  {'video_id': 'Co1-7LBk4XI', 'view_count': '552846', 'num_faces': 1},
#  {'video_id': 'Co1-7LBk4XI', 'view_count': '552867', 'num_faces': 1},
#  {'video_id': 'Cq7rTzwZaT4', 'view_count': '72469', 'num_faces': 1},
#  {'video_id': 'CwFLR1fto8c', 'view_count': '87910', 'num_faces': 1},
#  {'video_id': 'Cym6vyyE730', 'view_count': '14832086', 'num_faces': 1},
#  {'video_id': 'Cz2mFOJLaRI', 'view_count': '207220', 'num_faces': 1},
#  {'video_id': 'D14mpT6KBaU', 'view_count': '66861', 'num_faces': 1},
#  {'video_id': 'D1nXYfanouw', 'view_count': '251360', 'num_faces': 1},
#  {'video_id': 'D1nXYfanouw', 'view_count': '251389', 'num_faces': 1},
#  {'video_id': 'D2pWpPkjSDI', 'view_count': '1532626', 'num_faces': 1},
#  {'video_id': 'D3xn2_BQY24', 'view_count': '4094402', 'num_faces': 1},
#  {'video_id': 'D6QEiOdK7fM', 'view_count': '5341', 'num_faces': 2},
#  {'video_id': 'D6t3GtF916U', 'view_count': '24167', 'num_faces': 1},
#  {'video_id': 'DBafeHPFJEM', 'view_count': '6433775', 'num_faces': 1},
#  {'video_id': 'DBxyIJ2gkxc', 'view_count': '453905', 'num_faces': 1},
#  {'video_id': 'DDrGBG8aDGc', 'view_count': '233396', 'num_faces': 1},
#  {'video_id': 'DESC6FAQ-ck', 'view_count': '78753', 'num_faces': 1},
#  {'video_id': 'DHBGlzCyDt0', 'view_count': '5001410', 'num_faces': 1},
#  {'video_id': 'DHX26yQCVWM', 'view_count': '885752', 'num_faces': 1},
#  {'video_id': 'DHyWeSOEgd4', 'view_count': '128545', 'num_faces': 1},
#  {'video_id': 'DKmbORm658Y', 'view_count': '35459', 'num_faces': 1},
#  {'video_id': 'DNWa8rEvqBw', 'view_count': '291332', 'num_faces': 1},
#  {'video_id': 'DOsVpef-Jgs', 'view_count': '3090', 'num_faces': 1},
#  {'video_id': 'DQ4jL8RIdR8', 'view_count': '419668', 'num_faces': 1},
#  {'video_id': 'DRFnn7ILk6o', 'view_count': '15601', 'num_faces': 1},
#  {'video_id': 'DVN9J-SewEw', 'view_count': '1754952', 'num_faces': 2},
#  {'video_id': 'DVN9J-SewEw', 'view_count': '1755270', 'num_faces': 2},
#  {'video_id': 'DWrMubESP7M', 'view_count': '438881', 'num_faces': 1},
#  {'video_id': 'DZ_BvTb7Css', 'view_count': '818807', 'num_faces': 1},
#  {'video_id': 'D_gkHpZ2oRI', 'view_count': '2126612', 'num_faces': 1},
#  {'video_id': 'DbPbj1UoAJg', 'view_count': '1069471', 'num_faces': 1},
#  {'video_id': 'DdWbUSq7zEA', 'view_count': '5540853', 'num_faces': 1},
#  {'video_id': 'DhV5QphIK-U', 'view_count': '62559889', 'num_faces': 1},
#  {'video_id': 'Dkvn551H3-U', 'view_count': '4296602', 'num_faces': 1},
#  {'video_id': 'DoQuVsGQsgU', 'view_count': '10180', 'num_faces': 1},
#  {'video_id': 'DpE5cBgl11U', 'view_count': '2128747', 'num_faces': 2},
#  {'video_id': 'Dpl8wqGceZk', 'view_count': '5417', 'num_faces': 1},
#  {'video_id': 'DsJ-Ypz2jn4', 'view_count': '151693', 'num_faces': 1},
#  {'video_id': 'DsNPNfVUpDs', 'view_count': '160776', 'num_faces': 2},
#  {'video_id': 'Du7fOoW_euE', 'view_count': '1091175', 'num_faces': 1},
#  {'video_id': 'DyIHPT6U1Qc', 'view_count': '5264255', 'num_faces': 2},
#  {'video_id': 'DyIHPT6U1Qc', 'view_count': '5264786', 'num_faces': 2},
#  {'video_id': 'DynaLyMWfGc', 'view_count': '414722', 'num_faces': 1},
#  {'video_id': 'E39QvGBc3vE', 'view_count': '30', 'num_faces': 1},
#  {'video_id': 'E5b8HC1-6RE', 'view_count': '11197', 'num_faces': 1},
#  {'video_id': 'E5pqKBIh8tg', 'view_count': '3397986', 'num_faces': 1},
#  {'video_id': 'E6IL58JHfvo', 'view_count': '719', 'num_faces': 3},
#  {'video_id': 'E6ZOI61UUZA', 'view_count': '777771', 'num_faces': 1},
#  {'video_id': 'E7Dsh6JkOgg', 'view_count': '52311', 'num_faces': 1},
#  {'video_id': 'EBp2hLzUBws', 'view_count': '288818', 'num_faces': 1},
#  {'video_id': 'EBp2hLzUBws', 'view_count': '288851', 'num_faces': 1},
#  {'video_id': 'EBp2hLzUBws', 'view_count': '288899', 'num_faces': 1},
#  {'video_id': 'EChrsxcLJKg', 'view_count': '170679516', 'num_faces': 1},
#  {'video_id': 'EDE10UUnAzM', 'view_count': '82120246', 'num_faces': 2},
#  {'video_id': 'EE2SIdd5NsQ', 'view_count': '58249', 'num_faces': 1},
#  {'video_id': 'EEkrGgngJHA', 'view_count': '4725', 'num_faces': 1},
#  {'video_id': 'EF4gcGf-S6A', 'view_count': '1386617', 'num_faces': 1},
#  {'video_id': 'EHckdxPd4qw', 'view_count': '4733222', 'num_faces': 1},
#  {'video_id': 'EHckdxPd4qw', 'view_count': '4733223', 'num_faces': 1},
#  {'video_id': 'EHckdxPd4qw', 'view_count': '4733232', 'num_faces': 1},
#  {'video_id': 'EIpqNu9OqUs', 'view_count': '438', 'num_faces': 1},
#  {'video_id': 'EKKCAr4Y1Wc', 'view_count': '1484520', 'num_faces': 1},
#  {'video_id': 'EL8zktkUZU0', 'view_count': '714088', 'num_faces': 1},
#  {'video_id': 'ELYyCw6Ywr8', 'view_count': '7516468', 'num_faces': 1},
#  {'video_id': 'EO7azmchNnU', 'view_count': '1922200', 'num_faces': 2},
#  {'video_id': 'EOX6PAFMy3Y', 'view_count': '846035', 'num_faces': 1},
#  {'video_id': 'EOrHHtTZ29M', 'view_count': '1313929', 'num_faces': 1},
#  {'video_id': 'EP1_aLzdmsw', 'view_count': '7932082', 'num_faces': 2},
#  {'video_id': 'EQsMctI0OxI', 'view_count': '12880939', 'num_faces': 1},
#  {'video_id': 'EQsMctI0OxI', 'view_count': '12882469', 'num_faces': 1},
#  {'video_id': 'EQsMctI0OxI', 'view_count': '12884129', 'num_faces': 1},
#  {'video_id': 'EQsMctI0OxI', 'view_count': '12884821', 'num_faces': 1},
#  {'video_id': 'EUcvdGfGEj0', 'view_count': '5480731', 'num_faces': 1},
#  {'video_id': 'EVyHHzkW_Ro', 'view_count': '247158', 'num_faces': 1},
#  {'video_id': 'EX0QlCV4B_U', 'view_count': '4435299', 'num_faces': 1},
#  {'video_id': 'E_H3bcIwan8', 'view_count': '135241', 'num_faces': 1},
#  {'video_id': 'E_zf3gdVDEY', 'view_count': '2125048', 'num_faces': 1},
#  {'video_id': 'Ec0EWkjxQ0E', 'view_count': '139522', 'num_faces': 1},
#  {'video_id': 'EhHebSzkXw0', 'view_count': '13546', 'num_faces': 1},
#  {'video_id': 'EkJfZFpsJ6Y', 'view_count': '907011', 'num_faces': 1},
#  {'video_id': 'EkJfZFpsJ6Y', 'view_count': '907069', 'num_faces': 1},
#  {'video_id': 'Em1mSDz7lPc', 'view_count': '5564632', 'num_faces': 1},
#  {'video_id': 'EmEpJewSZDA', 'view_count': '412992', 'num_faces': 1},
#  {'video_id': 'EmEpJewSZDA', 'view_count': '413052', 'num_faces': 1},
#  {'video_id': 'EoyT5PH8iQU', 'view_count': '439152', 'num_faces': 1},
#  {'video_id': 'EqdxY34Y6LA', 'view_count': '1652', 'num_faces': 1},
#  {'video_id': 'ErPMQKqW6xE', 'view_count': '905', 'num_faces': 1},
#  {'video_id': 'F0Gaem7Ox-I', 'view_count': '9368', 'num_faces': 1},
#  {'video_id': 'F1wtJEGloXo', 'view_count': '17550', 'num_faces': 2},
#  {'video_id': 'F4n_rIyGH2o', 'view_count': '24719', 'num_faces': 1},
#  {'video_id': 'F6uSZh2P4-w', 'view_count': '14133', 'num_faces': 2},
#  {'video_id': 'F7ZXEzUnvUg', 'view_count': '3027830', 'num_faces': 1},
#  {'video_id': 'F9GKRuiH4-U', 'view_count': '205975', 'num_faces': 1},
#  {'video_id': 'F9GKRuiH4-U', 'view_count': '205986', 'num_faces': 1},
#  {'video_id': 'F9GKRuiH4-U', 'view_count': '205988', 'num_faces': 1},
#  {'video_id': 'FAUgk8lezn8', 'view_count': '7633312', 'num_faces': 1},
#  {'video_id': 'FB2OHSmMm7A', 'view_count': '72277', 'num_faces': 1},
#  {'video_id': 'FB3XjxuHvsU', 'view_count': '431986', 'num_faces': 1},
#  {'video_id': 'FBJs6RqrFDI', 'view_count': '747700', 'num_faces': 2},
#  {'video_id': 'FEn_A3Jg6sM', 'view_count': '1834623', 'num_faces': 1},
#  {'video_id': 'FFQNoOWSLO4', 'view_count': '31177', 'num_faces': 2},
#  {'video_id': 'FG38rne8igc', 'view_count': '1081', 'num_faces': 1},
#  {'video_id': 'FJCTzmZPYZo', 'view_count': '28475', 'num_faces': 1},
#  {'video_id': 'FKIUZfyr_ew', 'view_count': '2736135', 'num_faces': 1},
#  {'video_id': 'FPuIy-xnm8k', 'view_count': '29473', 'num_faces': 1},
#  {'video_id': 'FQYTTMA90yg', 'view_count': '61257871', 'num_faces': 1},
#  {'video_id': 'FW8iCBEDv6o', 'view_count': '8332946', 'num_faces': 1},
#  {'video_id': 'FW8iCBEDv6o', 'view_count': '8334118', 'num_faces': 1},
#  {'video_id': 'F_M04Gi5ckc', 'view_count': '648017', 'num_faces': 1},
#  {'video_id': 'FaoXeJt6WnQ', 'view_count': '43087', 'num_faces': 1},
#  {'video_id': 'FbKqfDOFRiw', 'view_count': '3160045', 'num_faces': 1},
#  {'video_id': 'Fbsmc2H3w7U', 'view_count': '7881772', 'num_faces': 1},
#  {'video_id': 'FcMf3L-2WPQ', 'view_count': '3577875', 'num_faces': 1},
#  {'video_id': 'FdqNLlfkOyU', 'view_count': '341556', 'num_faces': 1},
#  {'video_id': 'Fiiib9oqTB0', 'view_count': '6041', 'num_faces': 1},
#  {'video_id': 'FjMTg9UMBhA', 'view_count': '197559', 'num_faces': 1},
#  {'video_id': 'FkGQ5n1LRx8', 'view_count': '6393', 'num_faces': 1},
#  {'video_id': 'Fkb78uCbFe4', 'view_count': '481322', 'num_faces': 2},
#  {'video_id': 'FmjY0ZAJKZA', 'view_count': '39392472', 'num_faces': 1},
#  {'video_id': 'Fn97aG_E2Hs', 'view_count': '1823430', 'num_faces': 1},
#  {'video_id': 'Fo_ctINcsdY', 'view_count': '12910680', 'num_faces': 1},
#  {'video_id': 'Fp0vzRJpSHk', 'view_count': '1225', 'num_faces': 1},
#  {'video_id': 'G-kHqEpPkyM', 'view_count': '224760', 'num_faces': 1},
#  {'video_id': 'G1ZtJ2cG-u0', 'view_count': '31', 'num_faces': 1},
#  {'video_id': 'G3qgPEs-_J4', 'view_count': '16', 'num_faces': 1},
#  {'video_id': 'G3y8i2g-sao', 'view_count': '102492', 'num_faces': 1},
#  {'video_id': 'G4edGPUXJw4', 'view_count': '487756', 'num_faces': 1},
#  {'video_id': 'G8-bAk6PN5E', 'view_count': '41458', 'num_faces': 1},
#  {'video_id': 'G855TtsV33w', 'view_count': '17121', 'num_faces': 1},
#  {'video_id': 'G86feRfNaRQ', 'view_count': '11027167', 'num_faces': 2},
#  {'video_id': 'GB57gRKqTg8', 'view_count': '11995519', 'num_faces': 1},
#  {'video_id': 'GBOlHXZoUPM', 'view_count': '104301', 'num_faces': 1},
#  {'video_id': 'GCSr9vWoNIA', 'view_count': '463669', 'num_faces': 1},
#  {'video_id': 'GCiXtjxE2bQ', 'view_count': '328925', 'num_faces': 1},
#  {'video_id': 'GHB7IlUeZ3w', 'view_count': '1666977', 'num_faces': 1},
#  {'video_id': 'GJGChV6sW4k', 'view_count': '21780269', 'num_faces': 1},
#  {'video_id': 'GNnPp_kjXJc', 'view_count': '1145436', 'num_faces': 2},
#  {'video_id': 'GPIJTGSy4Ts', 'view_count': '1247899', 'num_faces': 1},
#  {'video_id': 'GPIJTGSy4Ts', 'view_count': '1247925', 'num_faces': 1},
#  {'video_id': 'GPIJTGSy4Ts', 'view_count': '124802', 'num_faces': 1},
#  {'video_id': 'GTvG8BAEOpA', 'view_count': '185587', 'num_faces': 1},
#  {'video_id': 'GU0GHr47iYo', 'view_count': '2906536', 'num_faces': 1},
#  {'video_id': 'GVCrTUeIvMY', 'view_count': '3176860', 'num_faces': 1},
#  {'video_id': 'GXx-AvBhA4k', 'view_count': '42', 'num_faces': 1},
#  {'video_id': 'GgmEBxwOIEg', 'view_count': '5884266', 'num_faces': 2},
#  {'video_id': 'GiTYvTa6spY', 'view_count': '349375', 'num_faces': 1},
#  {'video_id': 'GkQNqb_vM3E', 'view_count': '764021', 'num_faces': 1},
#  {'video_id': 'Gsz5fQm00Qs', 'view_count': '5895', 'num_faces': 1},
#  {'video_id': 'GuARzjxs83o', 'view_count': '3730896', 'num_faces': 1},
#  {'video_id': 'Gwr5WIMDSfI', 'view_count': '345', 'num_faces': 1},
#  {'video_id': 'H0QdAXuc-2w', 'view_count': '51436', 'num_faces': 1},
#  {'video_id': 'H6JdemYleCc', 'view_count': '140941', 'num_faces': 1},
#  {'video_id': 'H6zv_4kAQjo', 'view_count': '435912', 'num_faces': 1},
#  {'video_id': 'H7cplJ-gQZg', 'view_count': '3045', 'num_faces': 2},
# ...
#  {'video_id': 'JWPNrogPKLw', 'view_count': '93', 'num_faces': 1},
#  {'video_id': 'JWaJbfJrhIM', 'view_count': '206', 'num_faces': 1},
#  {'video_id': 'JYdCltjvrxg', 'view_count': '314790', 'num_faces': 1},
#  {'video_id': 'J_voxyyBryM', 'view_count': '23006497', 'num_faces': 1},
#  {'video_id': 'JcUba3seAoA', 'view_count': '542', 'num_faces': 2},
#  {'video_id': 'JelR4ZFWP8c', 'view_count': '38216', 'num_faces': 1},
#  {'video_id': 'JelR4ZFWP8c', 'view_count': '38217', 'num_faces': 1},
#  {'video_id': 'JelR4ZFWP8c', 'view_count': '38218', 'num_faces': 1},
#  {'video_id': 'JetuVC8NCHw', 'view_count': '3083827', 'num_faces': 1},
#  {'video_id': 'JfXHigyWENQ', 'view_count': '19623', 'num_faces': 1},
#  {'video_id': 'Jfbjr-U2dDM', 'view_count': '81863', 'num_faces': 1},
#  {'video_id': 'Ji2jsaawnb4', 'view_count': '127688', 'num_faces': 1},
#  {'video_id': 'Jj6qKAD1BLQ', 'view_count': '105972', 'num_faces': 1},
#  {'video_id': 'JkbSFA_28fc', 'view_count': '1374692', 'num_faces': 2},
#  {'video_id': 'JopQY0ZEGEI', 'view_count': '556650', 'num_faces': 1},
#  {'video_id': 'JpbLxd8gbj8', 'view_count': '813832', 'num_faces': 1},
#  {'video_id': 'JpfKi-FKN8U', 'view_count': '1732798', 'num_faces': 1},
#  {'video_id': 'Jqj2770kI44', 'view_count': '3027170', 'num_faces': 3},
#  {'video_id': 'Jqj2770kI44', 'view_count': '3027519', 'num_faces': 3},
#  {'video_id': 'JwxcV_U_LSw', 'view_count': '74829', 'num_faces': 1},
#  {'video_id': 'JxtM0_2I-T4', 'view_count': '1072096', 'num_faces': 1},
#  {'video_id': 'Jy5GGL2jlpw', 'view_count': '425', 'num_faces': 1},
#  {'video_id': 'K-hiDOPAG-4', 'view_count': '90102', 'num_faces': 1},
#  {'video_id': 'K3ibmOAtIXs', 'view_count': '59123', 'num_faces': 1},
#  {'video_id': 'K4faEgzst1E', 'view_count': '257978', 'num_faces': 1},
#  {'video_id': 'K4oxLrs51tU', 'view_count': '157929', 'num_faces': 1},
#  {'video_id': 'K5m-F6SXqaA', 'view_count': '271', 'num_faces': 1},
#  {'video_id': 'K9ImElASlzE', 'view_count': '23969', 'num_faces': 1},
#  {'video_id': 'K9e5ppi-6hs', 'view_count': '5297', 'num_faces': 2},
#  {'video_id': 'KCOSfU_x0yY', 'view_count': '34401', 'num_faces': 2},
#  {'video_id': 'KCnbR9hfU5Q', 'view_count': '4579846', 'num_faces': 1},
#  {'video_id': 'KEzoDiove-I', 'view_count': '7308308', 'num_faces': 1},
#  {'video_id': 'KG6X6Zn4Io0', 'view_count': '478918', 'num_faces': 1},
#  {'video_id': 'KGYm8UOEO5g', 'view_count': '1005738', 'num_faces': 2},
#  {'video_id': 'KHEZCXfyxjU', 'view_count': '1547670', 'num_faces': 1},
#  {'video_id': 'KLl4HLGkNMk', 'view_count': '9788883', 'num_faces': 1},
#  {'video_id': 'KMaJUGyv_98', 'view_count': '6587856', 'num_faces': 1},
#  {'video_id': 'KMaJUGyv_98', 'view_count': '6588431', 'num_faces': 1},
#  {'video_id': 'KMaJUGyv_98', 'view_count': '6589093', 'num_faces': 1},
#  {'video_id': 'KN_aaM6SKoo', 'view_count': '743571', 'num_faces': 2},
#  {'video_id': 'KObyc3yXe_I', 'view_count': '506', 'num_faces': 1},
#  {'video_id': 'KUrXv9YRuU8', 'view_count': '1460', 'num_faces': 1},
#  {'video_id': 'KW8yIx1CuJM', 'view_count': '493709', 'num_faces': 2},
#  {'video_id': 'K_EVYjZwmlc', 'view_count': '4965100', 'num_faces': 1},
#  {'video_id': 'K_uYb17XfVY', 'view_count': '38049', 'num_faces': 1},
#  {'video_id': 'Ka00hBtzhDg', 'view_count': '2118399', 'num_faces': 1},
#  {'video_id': 'Kb2GDdU_fB4', 'view_count': '3107', 'num_faces': 1},
#  {'video_id': 'KbN1XkNmPRA', 'view_count': '5', 'num_faces': 1},
#  {'video_id': 'KcTuLa7ZRXY', 'view_count': '69241', 'num_faces': 3},
#  {'video_id': 'Kdte1TJkZCY', 'view_count': '12671871', 'num_faces': 1},
#  {'video_id': 'KeonfTtZclI', 'view_count': '6227', 'num_faces': 1},
#  {'video_id': 'Kg-SGNhFbCw', 'view_count': '96717', 'num_faces': 1},
#  {'video_id': 'KgANOUT7v7k', 'view_count': '17846475', 'num_faces': 1},
#  {'video_id': 'Kk_BiUWdm6A', 'view_count': '2808115', 'num_faces': 1},
#  {'video_id': 'KmpJNFCdMg4', 'view_count': '2030', 'num_faces': 1},
#  {'video_id': 'Kn3Oq7p6TYI', 'view_count': '1576390', 'num_faces': 1},
#  {'video_id': 'KohwrjUIpuw', 'view_count': '205441', 'num_faces': 1},
#  {'video_id': 'KpAUeaEFz3Y', 'view_count': '2255999', 'num_faces': 1},
#  {'video_id': 'Kq9Yl6EpuZg', 'view_count': '6204550', 'num_faces': 1},
#  {'video_id': 'Kr740jrEmf0', 'view_count': '2073189', 'num_faces': 1},
#  {'video_id': 'KrD43_6pDZg', 'view_count': '163', 'num_faces': 1},
#  {'video_id': 'KtXF96oWZV8', 'view_count': '1446180', 'num_faces': 2},
#  {'video_id': 'KtXF96oWZV8', 'view_count': '1446241', 'num_faces': 2},
#  {'video_id': 'KvMwhgPdH9I', 'view_count': '18781819', 'num_faces': 1},
#  {'video_id': 'Kwo3NSe_zmc', 'view_count': '25621', 'num_faces': 1},
#  {'video_id': 'L1rcAxZjym0', 'view_count': '2257105', 'num_faces': 2},
#  {'video_id': 'L3SfRohoSdA', 'view_count': '1449922', 'num_faces': 1},
#  {'video_id': 'L3av2tWEcN8', 'view_count': '76832', 'num_faces': 2},
#  {'video_id': 'L4cuV_f20XA', 'view_count': '694207', 'num_faces': 3},
#  {'video_id': 'L6TBvTW0cJ4', 'view_count': '3967478', 'num_faces': 1},
#  {'video_id': 'L9EQGqJp7qw', 'view_count': '13345', 'num_faces': 1},
#  {'video_id': 'LB8rrS7sb64', 'view_count': '2335809', 'num_faces': 1},
#  {'video_id': 'LB8rrS7sb64', 'view_count': '2335891', 'num_faces': 1},
#  {'video_id': 'LB8rrS7sb64', 'view_count': '2336027', 'num_faces': 1},
#  {'video_id': 'LBSYYZnOHJI', 'view_count': '28', 'num_faces': 1},
#  {'video_id': 'LBoPQwPlgu0', 'view_count': '14525775', 'num_faces': 1},
#  {'video_id': 'LBoPQwPlgu0', 'view_count': '14528112', 'num_faces': 1},
#  {'video_id': 'LFO2PhgnJcw', 'view_count': '1488850', 'num_faces': 1},
#  {'video_id': 'LG3Fumx46hg', 'view_count': '153391', 'num_faces': 1},
#  {'video_id': 'LKspqI-BluY', 'view_count': '273485', 'num_faces': 1},
#  {'video_id': 'LLonEkjjM3M', 'view_count': '4518988', 'num_faces': 1},
#  {'video_id': 'LLonEkjjM3M', 'view_count': '4519000', 'num_faces': 1},
#  {'video_id': 'LMA5aqJzWM8', 'view_count': '12', 'num_faces': 1},
#  {'video_id': 'LMbCIZ9ItqQ', 'view_count': '757233', 'num_faces': 1},
#  {'video_id': 'LNTzgZhk88k', 'view_count': '245116', 'num_faces': 1},
#  {'video_id': 'LPIe39IDHys', 'view_count': '13', 'num_faces': 1},
#  {'video_id': 'LUR2JK9umTI', 'view_count': '7', 'num_faces': 1},
#  {'video_id': 'LVpUKzYkauA', 'view_count': '21240', 'num_faces': 1},
#  {'video_id': 'LWwcqLj0m3E', 'view_count': '3111', 'num_faces': 1},
#  {'video_id': 'LXlSm8iuZn0', 'view_count': '569482', 'num_faces': 1},
#  {'video_id': 'LYUKvSH-zX4', 'view_count': '615085', 'num_faces': 1},
#  {'video_id': 'Lb-H9wvukmQ', 'view_count': '595983', 'num_faces': 1},
#  {'video_id': 'LeQ_B16EqrU', 'view_count': '23252953', 'num_faces': 1},
#  {'video_id': 'LkOMIsEen1g', 'view_count': '3540351', 'num_faces': 1},
#  {'video_id': 'LlUeE7tdTP4', 'view_count': '1388995', 'num_faces': 1},
#  {'video_id': 'Lm6j1zVXMRI', 'view_count': '119', 'num_faces': 1},
#  {'video_id': 'LmDAFfX1_zc', 'view_count': '607202', 'num_faces': 1},
#  {'video_id': 'Lq2pqzPewQM', 'view_count': '4721702', 'num_faces': 1},
#  {'video_id': 'LsdkTn1E400', 'view_count': '73173', 'num_faces': 2},
#  {'video_id': 'LsdkTn1E400', 'view_count': '7317', 'num_faces': 2},
#  {'video_id': 'LwsXbc8dHQY', 'view_count': '102432', 'num_faces': 1},
#  {'video_id': 'LyFAAqVIDf8', 'view_count': '961', 'num_faces': 1},
#  {'video_id': 'M0r23Pvg0DE', 'view_count': '20860938', 'num_faces': 1},
#  {'video_id': 'M4CpH56_F38', 'view_count': '201125', 'num_faces': 1},
#  {'video_id': 'M4wN9-zK3sM', 'view_count': '22762', 'num_faces': 1},
#  {'video_id': 'M5s52CB1e_4', 'view_count': '1787692', 'num_faces': 1},
#  {'video_id': 'M7Ox4GdyZAc', 'view_count': '746447', 'num_faces': 2},
#  {'video_id': 'M8hqJ-GHh5U', 'view_count': '13642', 'num_faces': 1},
#  {'video_id': 'MB-YRjPjYBU', 'view_count': '25320150', 'num_faces': 1},
#  {'video_id': 'MB4TLXwmS_I', 'view_count': '811541', 'num_faces': 1},
#  {'video_id': 'MK5mYv7EdEc', 'view_count': '1', 'num_faces': 1},
#  {'video_id': 'MKUefNOw3MI', 'view_count': '592587', 'num_faces': 1},
#  {'video_id': 'MKXYmHoLZnE', 'view_count': '17870685', 'num_faces': 1},
#  {'video_id': 'MLOttTC-pMQ', 'view_count': '142289', 'num_faces': 1},
#  {'video_id': 'MLr2-DHx_us', 'view_count': '41668', 'num_faces': 1},
#  {'video_id': 'MPwKAIHOm7U', 'view_count': '1635107', 'num_faces': 1},
#  {'video_id': 'MPwKAIHOm7U', 'view_count': '1635302', 'num_faces': 1},
#  {'video_id': 'MSKZxL2D4Uo', 'view_count': '7618326', 'num_faces': 1},
#  {'video_id': 'MTo3n1oevAU', 'view_count': '7678', 'num_faces': 1},
#  {'video_id': 'MWtIcCVTaIQ', 'view_count': '78543', 'num_faces': 1},
#  {'video_id': 'MZGuOowcEqk', 'view_count': '11019', 'num_faces': 1},
#  {'video_id': 'M_GScapivrQ', 'view_count': '1667949', 'num_faces': 1},
#  {'video_id': 'MbaEpwP6l4w', 'view_count': '22107', 'num_faces': 1},
#  {'video_id': 'MdSPdunnm_U', 'view_count': '1513698', 'num_faces': 1},
#  {'video_id': 'MeZD3AWj4jY', 'view_count': '225681', 'num_faces': 1},
#  {'video_id': 'Mf9SZoFzYb0', 'view_count': '171', 'num_faces': 1},
#  {'video_id': 'Mh4fc41AS80', 'view_count': '3688873', 'num_faces': 1},
#  {'video_id': 'Mh4rfFan6RI', 'view_count': '371358', 'num_faces': 1},
#  {'video_id': 'MhNX4iiISs4', 'view_count': '4613988', 'num_faces': 1},
#  {'video_id': 'MkDob4_ETW8', 'view_count': '52617', 'num_faces': 1},
#  {'video_id': 'MlJeYZGznvc', 'view_count': '348646', 'num_faces': 1},
#  {'video_id': 'MmGNg3nreDA', 'view_count': '298460', 'num_faces': 2},
#  {'video_id': 'Mp-gbPADBZQ', 'view_count': '65138', 'num_faces': 1},
#  {'video_id': 'MuqAjh-u17I', 'view_count': '2370671', 'num_faces': 1},
#  {'video_id': 'MutyydX7xfQ', 'view_count': '3277893', 'num_faces': 1},
#  {'video_id': 'N-HMRIpEAK0', 'view_count': '2745388', 'num_faces': 1},
#  {'video_id': 'N1RxW9BM5j4', 'view_count': '44732', 'num_faces': 1},
#  {'video_id': 'N4pvvCToogM', 'view_count': '3289', 'num_faces': 1},
#  {'video_id': 'N87KY9yIgQ0', 'view_count': '2890789', 'num_faces': 1},
#  {'video_id': 'ND0tCMlVb3U', 'view_count': '13931', 'num_faces': 2},
#  {'video_id': 'NE84wI9XI2o', 'view_count': '13049053', 'num_faces': 2},
#  {'video_id': 'NE84wI9XI2o', 'view_count': '13049969', 'num_faces': 2},
#  {'video_id': 'NGJBImiAhnw', 'view_count': '518950', 'num_faces': 1},
#  {'video_id': 'NHC_Tlxyhn8', 'view_count': '16119040', 'num_faces': 1},
#  {'video_id': 'NImhGXyPDZs', 'view_count': '127785', 'num_faces': 1},
#  {'video_id': 'NImhGXyPDZs', 'view_count': '1278250', 'num_faces': 1},
#  {'video_id': 'NKXJqnLaSD4', 'view_count': '146547', 'num_faces': 1},
#  {'video_id': 'NKi-rQ52BDQ', 'view_count': '1816', 'num_faces': 1},
#  {'video_id': 'NMl8XiDiI5g', 'view_count': '3199', 'num_faces': 1},
#  {'video_id': 'NNDYnjhjXrc', 'view_count': '527867', 'num_faces': 1},
#  {'video_id': 'NRG4fIAgrUc', 'view_count': '1754491', 'num_faces': 1},
#  {'video_id': 'NRsJ9W9BBGI', 'view_count': '3209795', 'num_faces': 1},
#  {'video_id': 'NRvyVIQ1uJY', 'view_count': '30', 'num_faces': 1},
#  {'video_id': 'NTPEPBUZI7w', 'view_count': '18635086', 'num_faces': 1},
#  {'video_id': 'NTpfRZ4oRgM', 'view_count': '697643', 'num_faces': 1},
#  {'video_id': 'NW-NbV8nT-8', 'view_count': '10332', 'num_faces': 1},
#  {'video_id': 'N_h7vi6ttPo', 'view_count': '5522340', 'num_faces': 1},
#  {'video_id': 'Nd3jkEsqmJQ', 'view_count': '13001', 'num_faces': 1},
#  {'video_id': 'Nd8rIySTkGg', 'view_count': '731451', 'num_faces': 1},
#  {'video_id': 'NdSXjqsjAxk', 'view_count': '264452', 'num_faces': 1},
#  {'video_id': 'NedpxsAQRLc', 'view_count': '3753', 'num_faces': 1},
#  {'video_id': 'NhAQz_HRwbk', 'view_count': '9728589', 'num_faces': 1},
#  {'video_id': 'NnhaBf7rE0o', 'view_count': '469', 'num_faces': 1},
#  {'video_id': 'NoUV2C4mMSA', 'view_count': '462748', 'num_faces': 1},
#  {'video_id': 'NpXK5KLxPsU', 'view_count': '9', 'num_faces': 1},
#  {'video_id': 'Nxek6Z3WlIk', 'view_count': '80892', 'num_faces': 1},
#  {'video_id': 'O0DEPy8ado0', 'view_count': '16223', 'num_faces': 1},
#  {'video_id': 'O3Vsg9lZtQk', 'view_count': '3714913', 'num_faces': 1},
#  {'video_id': 'O3yHwdzKlcU', 'view_count': '11', 'num_faces': 1},
#  {'video_id': 'O44jE9DkAj8', 'view_count': '3678080', 'num_faces': 1},
#  {'video_id': 'O44jE9DkAj8', 'view_count': '3678173', 'num_faces': 1},
#  {'video_id': 'O5qvNaBxBpc', 'view_count': '606539', 'num_faces': 2},
#  {'video_id': 'ODU_QasrkcQ', 'view_count': '2433497', 'num_faces': 1},
#  {'video_id': 'OEfbaQAt_t0', 'view_count': '3805969', 'num_faces': 1},
#  {'video_id': 'OF06nDU8sWk', 'view_count': '811466', 'num_faces': 1},
#  {'video_id': 'OFh2eLWW4lg', 'view_count': '253026', 'num_faces': 1},
#  {'video_id': 'OKFBgVUQwMk', 'view_count': '1322330', 'num_faces': 2},
#  {'video_id': 'OKPeL7aSwCQ', 'view_count': '772421', 'num_faces': 1},
#  {'video_id': 'OMRZevAb_jU', 'view_count': '5080795', 'num_faces': 1},
#  {'video_id': 'OU1vo8xQSm8', 'view_count': '558979', 'num_faces': 1},
#  {'video_id': 'OUYNtQUnkaw', 'view_count': '15549870', 'num_faces': 1},
#  {'video_id': 'OWpVOz5rPLg', 'view_count': '6959158', 'num_faces': 1},
#  {'video_id': 'OXP07AY9JP4', 'view_count': '1288911', 'num_faces': 1},
#  {'video_id': 'ObQjlK9hOtw', 'view_count': '4140', 'num_faces': 1},
#  {'video_id': 'Ob_1D1Y76Ac', 'view_count': '1809422', 'num_faces': 1},
#  {'video_id': 'Ob_1D1Y76Ac', 'view_count': '1809545', 'num_faces': 1},
#  {'video_id': 'OdmwwAcFd2c', 'view_count': '75401', 'num_faces': 1},
#  {'video_id': 'OfW4AqZcGLo', 'view_count': '49547', 'num_faces': 1},
#  {'video_id': 'OfYVX5ZWxBA', 'view_count': '3193842', 'num_faces': 1},
#  {'video_id': 'Ofv7fbpPwVQ', 'view_count': '17102071', 'num_faces': 1},
#  {'video_id': 'OlH5MyorDNk', 'view_count': '527882', 'num_faces': 1},
#  {'video_id': 'OnpquCFlNMc', 'view_count': '777', 'num_faces': 2},
#  {'video_id': 'OqwlT3nrxp4', 'view_count': '6173', 'num_faces': 1},
#  {'video_id': 'Os7wVSlLkIE', 'view_count': '97', 'num_faces': 1},
#  {'video_id': 'OsPdhUQ0snE', 'view_count': '1315362', 'num_faces': 2},
#  {'video_id': 'Ot_yi1W5z9Q', 'view_count': '63526', 'num_faces': 2},
#  {'video_id': 'OvGRbRzTD38', 'view_count': '4662427', 'num_faces': 2},
#  {'video_id': 'OveTBCWfrqE', 'view_count': '16511', 'num_faces': 1},
#  {'video_id': 'OwVtoT590uU', 'view_count': '14331', 'num_faces': 1},
#  {'video_id': 'Oxj5aR_69x8', 'view_count': '886671', 'num_faces': 1},
#  {'video_id': 'OxuHeoPQ-Xc', 'view_count': '38106', 'num_faces': 1},
#  {'video_id': 'Oy_vZKyPqbU', 'view_count': '4106296', 'num_faces': 2},
#  {'video_id': 'P-QcHTfYG7E', 'view_count': '24256', 'num_faces': 2},
#  {'video_id': 'P1U_UQ6m-eU', 'view_count': '44161', 'num_faces': 1},
#  {'video_id': 'P1lmN6U3Fo8', 'view_count': '138988', 'num_faces': 1},
#  {'video_id': 'P38ru-PjZyw', 'view_count': '4946', 'num_faces': 2},
#  {'video_id': 'P5dqlktv6Uk', 'view_count': '7608', 'num_faces': 1},
#  {'video_id': 'P5jFRX_kgMQ', 'view_count': '704835', 'num_faces': 2},
#  {'video_id': 'P6D3x3eOq74', 'view_count': '1266', 'num_faces': 1},
#  {'video_id': 'P94lvyHTM_o', 'view_count': '736387', 'num_faces': 1},
#  {'video_id': 'PCTf_DkaBik', 'view_count': '1194412', 'num_faces': 1},
#  {'video_id': 'PE_Ug5zCvmI', 'view_count': '530461', 'num_faces': 1},
#  {'video_id': 'PIx0F-S-xWs', 'view_count': '72911', 'num_faces': 1},
#  {'video_id': 'PJAz4y-EhPA', 'view_count': '3336358', 'num_faces': 1},
#  {'video_id': 'PK78RL2hJXo', 'view_count': '63954471', 'num_faces': 1},
#  {'video_id': 'PK78RL2hJXo', 'view_count': '63957445', 'num_faces': 1},
#  {'video_id': 'PKQxwkAhLLw', 'view_count': '1360417', 'num_faces': 1},
#  {'video_id': 'PLTuwNB2RSY', 'view_count': '676275', 'num_faces': 1},
#  {'video_id': 'PLUu9mlJtV4', 'view_count': '365080', 'num_faces': 1},
#  {'video_id': 'PNdcfiNGlpw', 'view_count': '707029', 'num_faces': 1},
#  {'video_id': 'PQmjgitmv8U', 'view_count': '30663', 'num_faces': 1},
#  {'video_id': 'PRL5EumA9xc', 'view_count': '1856985', 'num_faces': 1},
#  {'video_id': 'PS9zjqBbKqw', 'view_count': '2147903', 'num_faces': 2},
#  {'video_id': 'PSLtHrVC_oc', 'view_count': '41626830', 'num_faces': 1},
#  {'video_id': 'PV5ar---9EM', 'view_count': '754396', 'num_faces': 1},
#  {'video_id': 'PXGkTgVgbrQ', 'view_count': '248143', 'num_faces': 1},
#  {'video_id': 'PYXVQ-FTMl0', 'view_count': '96326697', 'num_faces': 1},
#  {'video_id': 'PZ8O_qLZGxY', 'view_count': '5677537', 'num_faces': 1},
#  {'video_id': 'PZzuMQ8YZnc', 'view_count': '115', 'num_faces': 1},
#  ...]

# %%
import pandas as pd

# %%
face_list = pd.DataFrame(images)
face_list.drop([1016], axis=0, inplace=True)
face_list.drop([1378], axis=0, inplace=True)
face_list['view_count'] = pd.to_numeric(face_list['view_count'])
#face_list['view_count'][1016]
# Out:
# ZyNFltf09C

# %%
plt.scatter(face_list['view_count'],face_list['num_faces'])

# %%
import seaborn as sns

# %%
sns.regplot(face_list['view_count'],face_list['num_faces'])
# Out:
# /Users/nicolafriedrich/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='view_count', ylabel='num_faces'>

# %%
sns.boxplot(x = face_list['view_count'],hue = face_list['num_faces'])
# Out:
# <AxesSubplot:xlabel='view_count'>

# %%
#plt.plot(face_list['view_count']for face_list['num_count'] == 1)
plt.subplot(2,2,1)
plt.hist(face_list.loc[face_list['num_faces'] == 1]['view_count'],bins=50);
plt.subplot(2,2,2)
plt.hist(face_list.loc[face_list['num_faces'] == 2]['view_count'],bins=50);
plt.subplot(2,2,3)
plt.hist(face_list.loc[face_list['num_faces'] == 3]['view_count'],bins=50);
plt.subplot(2,2,4)
plt.hist(face_list.loc[face_list['num_faces'] == 4]['view_count'],bins=50);

# %%
plt.subplot(2,2,1)
sns.boxplot(face_list.loc[face_list['num_faces'] == 1]['view_count']);
plt.subplot(2,2,2)
sns.boxplot(face_list.loc[face_list['num_faces'] == 2]['view_count']);
plt.subplot(2,2,3)
sns.boxplot(face_list.loc[face_list['num_faces'] == 3]['view_count']);
plt.subplot(2,2,4)
sns.boxplot(face_list.loc[face_list['num_faces'] == 4]['view_count']);
# Out:
# /Users/nicolafriedrich/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/nicolafriedrich/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/nicolafriedrich/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/nicolafriedrich/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
face_list['num_faces'].value_counts()
# Out:
# 1    2062
# 2     282
# 3      26
# 4       3
# Name: num_faces, dtype: int64

# %%
face_list.groupby(face_list['num_faces']).mean()/1000000
# Out:
#            view_count
# num_faces
# 1            4.412051
# 2            4.021722
# 3            1.773900
# 4            0.668316
